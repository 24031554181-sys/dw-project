# %%
import pandas as pd
import numpy as np
import pycountry
import os, warnings, time, json, re
warnings.filterwarnings('ignore')

DATA_DIR = os.path.join(os.getcwd(), 'dataset')
print(f'Data directory: {DATA_DIR}')
print(f'Exists: {os.path.isdir(DATA_DIR)}')
# Out:
# Data directory: C:\Users\LENOVO\dw project\dataset
# Exists: True

# %% [markdown]
# ---
# ## 1. ETL — EXTRACT
# Membaca seluruh dataset CSV mentah dari folder dataset.

# %%
df_both       = pd.read_csv(os.path.join(DATA_DIR, 'penyebab utama kematian.csv'))
df_female     = pd.read_csv(os.path.join(DATA_DIR, 'female.csv'))
df_male       = pd.read_csv(os.path.join(DATA_DIR, 'male.csv'))
df_life_exp   = pd.read_csv(os.path.join(DATA_DIR, 'RELAY_WHS (3).csv'))
df_healthy_life = pd.read_csv(os.path.join(DATA_DIR, 'RELAY_WHS (5).csv'))

print('Dataset shape:')
print(f'  Mortality (both sexes) : {df_both.shape}')
print(f'  Mortality (female)     : {df_female.shape}')
print(f'  Mortality (male)       : {df_male.shape}')
print(f'  Life Expectancy        : {df_life_exp.shape}')
print(f'  Healthy Life Exp       : {df_healthy_life.shape}')

print('\nContoh data mortality:')
df_both.head(3)
# Out:
# Dataset shape:
#   Mortality (both sexes) : (24522, 5)
#   Mortality (female)     : (24522, 5)
#   Mortality (male)       : (24522, 5)
#   Life Expectancy        : (12936, 13)
#   Healthy Life Exp       : (12936, 13)
#
# Contoh data mortality:
#   DIM_COUNTRY_CODE  DIM_YEAR_CODE DIM_GHECAUSE_TITLE DIM_SEX_CODE  \
# 0              AFG           2021           Syphilis         BTSX
# 1              AFG           2021     Genital herpes         BTSX
# 2              AFG           2021         Diphtheria         BTSX
#
#    VAL_DTHS_RATE100K_NUMERIC
# 0                       1.46
# 1                       0.00
# 2                       0.11

# %%
print('Contoh data life expectancy:')
df_life_exp.head(3)
# Out:
# Contoh data life expectancy:
#                  IND_ID       IND_CODE IND_UUID   IND_PER_CODE  DIM_TIME  \
# 0  90E2E48WHOSIS_000001  WHOSIS_000001  90E2E48  WHOSIS_000001      2000
# 1  90E2E48WHOSIS_000001  WHOSIS_000001  90E2E48  WHOSIS_000001      2000
# 2  90E2E48WHOSIS_000001  WHOSIS_000001  90E2E48  WHOSIS_000001      2006
#
#   DIM_TIME_TYPE  DIM_GEO_CODE_M49 DIM_GEO_CODE_TYPE DIM_PUBLISH_STATE_CODE  \
# 0          YEAR               702           COUNTRY              PUBLISHED
# 1          YEAR               703           COUNTRY              PUBLISHED
# 2          YEAR               462           COUNTRY              PUBLISHED
#
#                      IND_NAME GEO_NAME_SHORT DIM_SEX   AMOUNT_N
# 0  Life expectancy (at birth)      Singapore  FEMALE  80.774170
# 1  Life expectancy (at birth)       Slovakia  FEMALE  77.405510
# 2  Life expectancy (at birth)       Maldives  FEMALE  75.095393

# %%
print('Contoh data healthy life expectancy:')
df_healthy_life.head(3)
# Out:
# Contoh data healthy life expectancy:
#                  IND_ID       IND_CODE IND_UUID   IND_PER_CODE  DIM_TIME  \
# 0  C64284DWHOSIS_000002  WHOSIS_000002  C64284D  WHOSIS_000002      2002
# 1  C64284DWHOSIS_000002  WHOSIS_000002  C64284D  WHOSIS_000002      2002
# 2  C64284DWHOSIS_000002  WHOSIS_000002  C64284D  WHOSIS_000002      2002
#
#   DIM_TIME_TYPE  DIM_GEO_CODE_M49 DIM_GEO_CODE_TYPE DIM_PUBLISH_STATE_CODE  \
# 0          YEAR               862           COUNTRY              PUBLISHED
# 1          YEAR               882           COUNTRY              PUBLISHED
# 2          YEAR               887           COUNTRY              PUBLISHED
#
#                              IND_NAME                      GEO_NAME_SHORT  \
# 0  Healthy life expectancy (at birth)  Venezuela (Bolivarian Republic of)
# 1  Healthy life expectancy (at birth)                               Samoa
# 2  Healthy life expectancy (at birth)                               Yemen
#
#   DIM_SEX   AMOUNT_N
# 0  FEMALE  66.668565
# 1  FEMALE  62.499757
# 2  FEMALE  54.872124

# %% [markdown]
# ---
# ## 2. ETL — TRANSFORM
# ### 2.1 Dimensional Modeling (Star Schema)
#
# **Skema:**
# - `dim_country` (country_id, country_code, country_name, m49_code)
# - `dim_year` (year_id, year)
# - `dim_cause` (cause_id, cause_name, cause_category)
# - `dim_sex` (sex_id, sex_code, sex_name)
# - `fact_mortality` (country_id, year_id, cause_id, sex_id, death_rate)
# - `fact_life_expectancy` (country_id, year_id, sex_id, life_expectancy, healthy_life_expectancy)

# %% [markdown]
# ### 2.2 Dimension: Country

# %%
iso3_codes = sorted(set(df_both['DIM_COUNTRY_CODE'].unique()))
print(f'Total negara (ISO3): {len(iso3_codes)}')

country_map = {}
for code in iso3_codes:
    try:
        c = pycountry.countries.get(alpha_3=code)
        if c:
            country_map[code] = {'country_name': c.name, 'm49_code': c.numeric}
        else:
            country_map[code] = {'country_name': code, 'm49_code': None}
    except:
        country_map[code] = {'country_name': code, 'm49_code': None}

dim_country = pd.DataFrame([
    {'country_code': k, 'country_name': v['country_name'], 'm49_code': v['m49_code']}
    for k, v in country_map.items()
])
dim_country['country_id'] = range(1, len(dim_country) + 1)

unmapped = dim_country[dim_country['m49_code'].isna()]
if len(unmapped) > 0:
    print(f'Negara tanpa M49: {unmapped["country_code"].tolist()}')
else:
    print('Semua negara berhasil di-mapping!')

print(f'dim_country: {dim_country.shape}')
dim_country.head(10)
# Out:
# Total negara (ISO3): 183
# Semua negara berhasil di-mapping!
# dim_country: (183, 4)
#   country_code          country_name m49_code  country_id
# 0          AFG           Afghanistan      004           1
# 1          AGO                Angola      024           2
# 2          ALB               Albania      008           3
# 3          ARE  United Arab Emirates      784           4
# 4          ARG             Argentina      032           5
# 5          ARM               Armenia      051           6
# 6          ATG   Antigua and Barbuda      028           7
# 7          AUS             Australia      036           8
# 8          AUT               Austria      040           9
# 9          AZE            Azerbaijan      031          10

# %% [markdown]
# ### 2.3 Dimension: Cause (dengan Kategori)

# %%
cause_categories = {
    'Communicable': [
        'Tuberculosis', 'HIV/AIDS', 'Diarrhoeal diseases', 'Lower respiratory infections',
        'Meningitis', 'Malaria', 'COVID-19', 'Measles', 'Tetanus', 'Diphtheria',
        'Whooping cough', 'Acute hepatitis B', 'Acute hepatitis C', 'Acute hepatitis E',
        'Acute hepatitis A', 'Syphilis', 'Genital herpes', 'Dengue', 'Rabies',
        'African trypanosomiasis', 'Chagas disease', 'Schistosomiasis', 'Leishmaniasis',
        'Echinococcosis', 'Food-bourne trematodes', 'Leprosy', 'Trachoma',
        'Trichomoniasis', 'Chlamydia', 'Gonorrhoea', 'Onchocerciasis',
        'Lymphatic filariasis', 'Hookworm disease', 'Ascariasis', 'Trichuriasis',
        'Cysticercosis', 'Yellow fever', 'Encephalitis', 'Upper respiratory infections',
        'Otitis media', 'Maternal conditions', 'Neonatal sepsis and infections',
        'Preterm birth complications', 'Birth asphyxia and birth trauma',
        'Protein-energy malnutrition', 'Vitamin A deficiency', 'Iodine deficiency',
        'Iron-deficiency anaemia'
    ],
    'Non-communicable': [
        'Ischaemic heart disease', 'Stroke', 'Chronic obstructive pulmonary disease',
        'Trachea, bronchus, lung cancers', 'Diabetes mellitus', 'Kidney diseases',
        'Hypertensive heart disease', 'Alzheimer disease and other dementias',
        'Colon and rectum cancers', 'Stomach cancer', 'Breast cancer',
        'Liver cancer', 'Pancreas cancer', 'Prostate cancer', 'Leukaemia',
        'Oesophagus cancer', 'Cervix uteri cancer', 'Ovary cancer',
        'Bladder cancer', 'Lymphomas, multiple myeloma', 'Brain and nervous system cancers',
        'Kidney cancer', 'Corpus uteri cancer', 'Gallbladder and biliary tract cancer',
        'Melanoma and other skin cancers', 'Thyroid cancer', 'Larynx cancer',
        'Mouth and oropharynx cancers', 'Cardiomyopathy, myocarditis, endocarditis',
        'Asthma', 'Cirrhosis of the liver', 'Peptic ulcer disease',
        'Gallbladder and biliary diseases', 'Pancreatitis', 'Appendicitis',
        'Paralytic ileus and intestinal obstruction', 'Inflammatory bowel disease',
        'Gastritis and duodenitis', 'Skin diseases', 'Rheumatic heart disease',
        'Parkinson disease', 'Epilepsy', 'Multiple sclerosis',
        'Alcohol use disorders', 'Drug use disorders', 'Depressive disorders',
        'Anxiety disorders', 'Schizophrenia', 'Bipolar disorder',
        'Eating disorders', 'Autism and Asperger syndrome',
        'Childhood behavioural disorders', 'Idiopathic intellectual disability',
        'Non-migraine headache', 'Migraine', 'Cataracts', 'Glaucoma',
        'Macular degeneration', 'Uncorrected refractive errors', 'Other hearing loss',
        'Other vision loss', 'Oral conditions', 'Back and neck pain',
        'Osteoarthritis', 'Rheumatoid arthritis', 'Gout', 'Benign prostatic hyperplasia',
        'Urolithiasis', 'Infertility', 'Gynecological diseases',
        'Congenital anomalies', 'Sudden infant death syndrome',
        'Sickle cell disorders and trait', 'Thalassaemias', 'Mesothelioma',
        'Testicular cancer'
    ],
    'Injury': [
        'Road injury', 'Falls', 'Drowning', 'Poisonings', 'Fire, heat and hot substances',
        'Exposure to mechanical forces', 'Self-harm', 'Interpersonal violence',
        'Collective violence and legal intervention', 'Natural disasters'
    ]
}

cause_to_cat = {c: cat for cat, causes in cause_categories.items() for c in causes}

causes = sorted(df_both['DIM_GHECAUSE_TITLE'].unique())
dim_cause = pd.DataFrame({
    'cause_id': range(1, len(causes) + 1),
    'cause_name': causes,
    'cause_category': [cause_to_cat.get(c, 'Other') for c in causes]
})

print(f'dim_cause: {dim_cause.shape}')
print('Distribusi kategori:')
print(dim_cause['cause_category'].value_counts())
dim_cause.head(5)
# Out:
# dim_cause: (134, 3)
# Distribusi kategori:
# cause_category
# Non-communicable    76
# Communicable        48
# Injury              10
# Name: count, dtype: int64
#    cause_id               cause_name cause_category
# 0         1        Acute hepatitis A   Communicable
# 1         2        Acute hepatitis B   Communicable
# 2         3        Acute hepatitis C   Communicable
# 3         4        Acute hepatitis E   Communicable
# 4         5  African trypanosomiasis   Communicable

# %% [markdown]
# ### 2.4 Dimension: Sex & Year

# %%
# Dimension Sex
dim_sex = pd.DataFrame({
    'sex_id': [1, 2, 3, 4],
    'sex_code': ['BTSX', 'FMLE', 'MLE', 'TOTAL'],
    'sex_name': ['Both sexes', 'Female', 'Male', 'Total']
})
print('dim_sex:')
print(dim_sex.to_string(index=False))

mortality_years = df_both['DIM_YEAR_CODE'].unique()
life_years = df_life_exp['DIM_TIME'].unique()
all_years = sorted(set(int(y) for y in list(mortality_years) + list(life_years)))

dim_year = pd.DataFrame({'year': all_years, 'year_id': range(1, len(all_years) + 1)})
print(f'\ndim_year: {dim_year.shape} — rentang {all_years[0]} s.d. {all_years[-1]}')
dim_year.head(10)
# Out:
# dim_sex:
#  sex_id sex_code   sex_name
#       1     BTSX Both sexes
#       2     FMLE     Female
#       3      MLE       Male
#       4    TOTAL      Total
#
# dim_year: (22, 2) — rentang 2000 s.d. 2021
#    year  year_id
# 0  2000        1
# 1  2001        2
# 2  2002        3
# 3  2003        4
# 4  2004        5
# 5  2005        6
# 6  2006        7
# 7  2007        8
# 8  2008        9
# 9  2009       10

# %% [markdown]
# ### 2.5 Fact Table: Mortality
#
# > **Periodic Extraction Simulation:** Data asli hanya 2021. Untuk memenuhi syarat span 1-2 tahun,
# > kita simulasikan batch periodik: Batch 1 (2021) = data asli + Batch 2 (2020) = replika dengan noise ±10%.

# %%
np.random.seed(42)

df_both_2020    = df_both.copy()
df_female_2020  = df_female.copy()
df_male_2020    = df_male.copy()

for df_sim in [df_both_2020, df_female_2020, df_male_2020]:
    df_sim['DIM_YEAR_CODE'] = 2020
    noise = np.random.uniform(0.90, 1.10, size=len(df_sim))
    df_sim['VAL_DTHS_RATE100K_NUMERIC'] = (
        df_sim['VAL_DTHS_RATE100K_NUMERIC'] * noise
    ).round(2)

print(' Simulasi Periodic Extraction')
print(f'Batch 1 (2021): {len(df_both):,} records (data asli)')
print(f'Batch 2 (2020): {len(df_both_2020):,} records (simulasi + noise)')

df_fact_mortality = pd.concat(
    [df_both, df_female, df_male,
     df_both_2020, df_female_2020, df_male_2020],
    ignore_index=True
)
print(f'Combined mortality (2020+2021): {df_fact_mortality.shape}')
print(f'  - 2021 records: {len(df_fact_mortality[df_fact_mortality["DIM_YEAR_CODE"]==2021])}')
print(f'  - 2020 records: {len(df_fact_mortality[df_fact_mortality["DIM_YEAR_CODE"]==2020])}')
# Out:
# === Simulasi Periodic Extraction ===
# Batch 1 (2021): 24,522 records (data asli)
# Batch 2 (2020): 24,522 records (simulasi + noise)
# Combined mortality (2020+2021): (147132, 5)
#   - 2021 records: 73566
#   - 2020 records: 73566

# %%
country_id_map = dict(zip(dim_country['country_code'], dim_country['country_id']))
cause_id_map   = dict(zip(dim_cause['cause_name'], dim_cause['cause_id']))
sex_id_map     = dict(zip(dim_sex['sex_code'], dim_sex['sex_id']))
year_id_map    = dict(zip(dim_year['year'], dim_year['year_id']))

df_fact_mortality['country_id'] = df_fact_mortality['DIM_COUNTRY_CODE'].map(country_id_map)
df_fact_mortality['cause_id']   = df_fact_mortality['DIM_GHECAUSE_TITLE'].map(cause_id_map)
df_fact_mortality['sex_id']     = df_fact_mortality['DIM_SEX_CODE'].map(sex_id_map)
df_fact_mortality['year_id']    = df_fact_mortality['DIM_YEAR_CODE'].map(year_id_map)
df_fact_mortality['death_rate'] = pd.to_numeric(
    df_fact_mortality['VAL_DTHS_RATE100K_NUMERIC'], errors='coerce'
)

fact_mortality = df_fact_mortality[
    ['country_id', 'year_id', 'cause_id', 'sex_id', 'death_rate']
].copy()

before = len(fact_mortality)
fact_mortality = fact_mortality.dropna()
print(f'fact_mortality: {len(fact_mortality):,} rows (dropped {before - len(fact_mortality)} unmapped)')

fact_mortality[['country_id', 'year_id', 'cause_id', 'sex_id']] = (
    fact_mortality[['country_id', 'year_id', 'cause_id', 'sex_id']].astype(int)
)

print(f'\nStatistik death_rate:')
print(fact_mortality['death_rate'].describe())
fact_mortality.head()
# Out:
# fact_mortality: 147,132 rows (dropped 0 unmapped)
#
# Statistik death_rate:
# count    147132.000000
# mean          5.821990
# std          23.077915
# min           0.000000
# 25%           0.000000
# 50%           0.190000
# 75%           2.650000
# max         720.900000
# Name: death_rate, dtype: float64
#    country_id  year_id  cause_id  sex_id  death_rate
# 0           1       22       119       1        1.46
# 1           1       22        52       1        0.00
# 2           1       22        38       1        0.11
# 3           1       22         5       1        0.00
# 4           1       22        34       1        0.00

# %% [markdown]
# ### 2.6 Fact Table: Life Expectancy

# %%
df_le_country  = df_life_exp[df_life_exp['DIM_GEO_CODE_TYPE'] == 'COUNTRY'].copy()
df_hle_country = df_healthy_life[df_healthy_life['DIM_GEO_CODE_TYPE'] == 'COUNTRY'].copy()

print(f'Life exp (country only): {df_le_country.shape}')
print(f'Healthy life exp (country only): {df_hle_country.shape}')

df_le = df_le_country[['DIM_TIME', 'DIM_GEO_CODE_M49', 'DIM_SEX', 'AMOUNT_N']].copy()
df_le.columns = ['year', 'm49_code', 'sex', 'life_expectancy']

df_hle = df_hle_country[['DIM_TIME', 'DIM_GEO_CODE_M49', 'DIM_SEX', 'AMOUNT_N']].copy()
df_hle.columns = ['year', 'm49_code', 'sex', 'healthy_life_expectancy']

fact_life = pd.merge(df_le, df_hle, on=['year', 'm49_code', 'sex'], how='outer')
print(f'fact_life (merged): {fact_life.shape}')

m49_to_country_code = {}
for _, row in dim_country.iterrows():
    if pd.notna(row['m49_code']):
        m49_to_country_code[int(row['m49_code'])] = row['country_code']

fact_life['m49_code'] = fact_life['m49_code'].astype(int)
fact_life['country_code'] = fact_life['m49_code'].map(m49_to_country_code)
fact_life['country_id'] = fact_life['country_code'].map(country_id_map)
fact_life['year_id'] = fact_life['year'].map(year_id_map)
fact_life['sex_id'] = fact_life['sex'].map({'FEMALE': 2, 'MALE': 3, 'TOTAL': 4})

before = len(fact_life)
fact_life = fact_life.dropna(subset=['country_id', 'year_id', 'sex_id'])
print(f'fact_life after mapping: {len(fact_life):,} rows (dropped {before - len(fact_life)})')

fact_life[['country_id', 'year_id', 'sex_id']] = (
    fact_life[['country_id', 'year_id', 'sex_id']].astype(int)
)

fact_life = fact_life[['country_id', 'year_id', 'sex_id', 'life_expectancy', 'healthy_life_expectancy']]
print(f'\nStatistik harapan hidup:')
print(fact_life[['life_expectancy', 'healthy_life_expectancy']].describe())
fact_life.head()
# Out:
# Life exp (country only): (12078, 13)
# Healthy life exp (country only): (12078, 13)
# fact_life (merged): (12078, 5)
# fact_life after mapping: 12,078 rows (dropped 0)
#
# Statistik harapan hidup:
#        life_expectancy  healthy_life_expectancy
# count     12078.000000             12078.000000
# mean         70.117161                60.991277
# std           8.917744                 7.455924
# min          36.599153                31.884329
# 25%          64.058075                56.071372
# 50%          71.759731                62.760557
# 75%          77.061597                66.656963
# max          87.371027                75.113417
#    country_id  year_id  sex_id  life_expectancy  healthy_life_expectancy
# 0           1        1       2        54.429579                46.154851
# 1           1        1       3        53.249991                45.943669
# 2           1        1       4        53.823326                46.027950
# 3           3        1       2        77.062201                66.808087
# 4           3        1       3        70.683987                62.425162

# %% [markdown]
# ---
# ## 3. ETL — LOAD (Supabase PostgreSQL)
#
# **Eksekusi DDL + Insert Data + Ukuran Database**

# %%
from sqlalchemy import create_engine, text
from sqlalchemy.exc import SQLAlchemyError
import getpass


DB_CONFIG = {
    'host': 'db.acynhugxakjqkpwqggmf.supabase.co',
    'port': 5432,
    'dbname': 'postgres',
    'user': 'postgres',
    'password': 'luckysuryar123'  # akan diisi via getpass
}

if DB_CONFIG['password'] is None:
    DB_CONFIG['password'] = getpass.getpass('Masukkan password Supabase PostgreSQL: ')

DB_URL = f"postgresql://{DB_CONFIG['user']}:{DB_CONFIG['password']}@{DB_CONFIG['host']}:{DB_CONFIG['port']}/{DB_CONFIG['dbname']}"
print(f'Connecting to: {DB_CONFIG["host"]}:{DB_CONFIG["port"]}/{DB_CONFIG["dbname"]}')

try:
    engine = create_engine(DB_URL, pool_pre_ping=True)
    with engine.connect() as conn:
        result = conn.execute(text('SELECT version()'))
        print('\nConnected! PostgreSQL version:')
        for row in result:
            print(f'  {row[0]}')
except Exception as e:
    print(f'ERROR: Gagal konek ke Supabase — {e}')
    print('Perbaiki kredensial DB_CONFIG di atas lalu jalankan ulang sel ini.')
# Out:
# Connecting to: db.acynhugxakjqkpwqggmf.supabase.co:5432/postgres
#
# Connected! PostgreSQL version:
#   PostgreSQL 17.6 on aarch64-unknown-linux-gnu, compiled by gcc (GCC) 15.2.0, 64-bit

# %% [markdown]
# ### 3.1 Eksekusi DDL
# Membuat tabel dimensi, fakt partisi, indeks, dan materialized views.

# %%
DDL = '''
-- =========================================================
-- DDL — Data Warehouse Kematian Global & Harapan Hidup
-- PostgreSQL + Extensions + Partition + Indexes + MV
-- =========================================================

-- 1. Extensions
CREATE EXTENSION IF NOT EXISTS pg_stat_statements;
CREATE EXTENSION IF NOT EXISTS pgcrypto;

-- 2. dim_country
CREATE TABLE IF NOT EXISTS dim_country (
    country_id    INTEGER PRIMARY KEY,
    country_code  VARCHAR(3) NOT NULL UNIQUE,
    country_name  VARCHAR(100) NOT NULL,
    m49_code      INTEGER
);

-- 3. dim_year
CREATE TABLE IF NOT EXISTS dim_year (
    year_id  INTEGER PRIMARY KEY,
    year     INTEGER NOT NULL
);

-- 4. dim_cause
CREATE TABLE IF NOT EXISTS dim_cause (
    cause_id        INTEGER PRIMARY KEY,
    cause_name      VARCHAR(200) NOT NULL,
    cause_category  VARCHAR(50) NOT NULL
);

-- 5. dim_sex
CREATE TABLE IF NOT EXISTS dim_sex (
    sex_id    INTEGER PRIMARY KEY,
    sex_code  VARCHAR(4) NOT NULL UNIQUE,
    sex_name  VARCHAR(20) NOT NULL
);

-- 6. fact_mortality (partitioned by year_id)
CREATE TABLE IF NOT EXISTS fact_mortality (
    country_id  INTEGER NOT NULL REFERENCES dim_country(country_id),
    year_id     INTEGER NOT NULL REFERENCES dim_year(year_id),
    cause_id    INTEGER NOT NULL REFERENCES dim_cause(cause_id),
    sex_id      INTEGER NOT NULL REFERENCES dim_sex(sex_id),
    death_rate  NUMERIC(12,6) NOT NULL,
    PRIMARY KEY (country_id, year_id, cause_id, sex_id)
) PARTITION BY LIST (year_id);

CREATE TABLE IF NOT EXISTS fact_mortality_2020 PARTITION OF fact_mortality
    FOR VALUES IN (2);
CREATE TABLE IF NOT EXISTS fact_mortality_2021 PARTITION OF fact_mortality
    FOR VALUES IN (1);

-- 7. fact_life_expectancy (partitioned by year_id)
CREATE TABLE IF NOT EXISTS fact_life_expectancy (
    country_id              INTEGER NOT NULL REFERENCES dim_country(country_id),
    year_id                 INTEGER NOT NULL REFERENCES dim_year(year_id),
    sex_id                  INTEGER NOT NULL REFERENCES dim_sex(sex_id),
    life_expectancy         NUMERIC(10,6),
    healthy_life_expectancy NUMERIC(10,6),
    PRIMARY KEY (country_id, year_id, sex_id)
) PARTITION BY LIST (year_id);
'''

partition_ddl = []
for _, row in dim_year.iterrows():
    partition_ddl.append(
        f"CREATE TABLE IF NOT EXISTS fact_life_{row['year']} PARTITION OF fact_life_expectancy "
        f"FOR VALUES IN ({row['year_id']});"
    )

INDEXES = '''
CREATE INDEX IF NOT EXISTS idx_fact_mortality_country ON fact_mortality(country_id);
CREATE INDEX IF NOT EXISTS idx_fact_mortality_cause   ON fact_mortality(cause_id);
CREATE INDEX IF NOT EXISTS idx_fact_mortality_sex     ON fact_mortality(sex_id);
CREATE INDEX IF NOT EXISTS idx_fact_mortality_year    ON fact_mortality(year_id);
CREATE INDEX IF NOT EXISTS idx_fact_life_country      ON fact_life_expectancy(country_id);
CREATE INDEX IF NOT EXISTS idx_fact_life_sex          ON fact_life_expectancy(sex_id);
CREATE INDEX IF NOT EXISTS idx_fact_life_year         ON fact_life_expectancy(year_id);
CREATE INDEX IF NOT EXISTS idx_dim_cause_category     ON dim_cause(cause_category);
'''

MAT_VIEWS = '''
CREATE MATERIALIZED VIEW IF NOT EXISTS mv_mortality_by_country AS
SELECT c.country_name, y.year, s.sex_name,
       ROUND(AVG(d.death_rate)::numeric, 4) AS avg_death_rate,
       ROUND(SUM(d.death_rate)::numeric, 4) AS total_death_rate,
       COUNT(*) AS record_count
FROM fact_mortality d
JOIN dim_country c ON c.country_id = d.country_id
JOIN dim_year y    ON y.year_id = d.year_id
JOIN dim_sex s     ON s.sex_id = d.sex_id
GROUP BY c.country_name, y.year, s.sex_name
ORDER BY c.country_name, y.year, s.sex_name;

CREATE MATERIALIZED VIEW IF NOT EXISTS mv_top_causes AS
SELECT cs.cause_name, cs.cause_category, y.year,
       ROUND(AVG(d.death_rate)::numeric, 4) AS avg_death_rate,
       ROUND(SUM(d.death_rate)::numeric, 4) AS total_death_rate
FROM fact_mortality d
JOIN dim_cause cs ON cs.cause_id = d.cause_id
JOIN dim_year y   ON y.year_id = d.year_id
WHERE d.sex_id = 1
GROUP BY cs.cause_name, cs.cause_category, y.year
ORDER BY avg_death_rate DESC;

CREATE MATERIALIZED VIEW IF NOT EXISTS mv_life_expectancy_trend AS
SELECT c.country_name, y.year, s.sex_name,
       ROUND(AVG(l.life_expectancy)::numeric, 2) AS avg_life_expectancy,
       ROUND(AVG(l.healthy_life_expectancy)::numeric, 2) AS avg_healthy_life_expectancy
FROM fact_life_expectancy l
JOIN dim_country c ON c.country_id = l.country_id
JOIN dim_year y    ON y.year_id = l.year_id
JOIN dim_sex s     ON s.sex_id = l.sex_id
GROUP BY c.country_name, y.year, s.sex_name
ORDER BY c.country_name, y.year;
'''

FULL_DDL = DDL + '\n'.join(partition_ddl) + '\n' + INDEXES + '\n' + MAT_VIEWS

print(f'DDL siap: {len(FULL_DDL):,} karakter')
print(f'  - Partisi mortality: 2 (2020, 2021)')
print(f'  - Partisi life exp: {len(partition_ddl)}')
print(f'  - Indexes: 8')
print(f'  - Materialized Views: 3')
# Out:
# DDL siap: 6,457 karakter
#   - Partisi mortality: 2 (2020, 2021)
#   - Partisi life exp: 22
#   - Indexes: 8
#   - Materialized Views: 3

# %%
print('>Mengeksekusi DDL')
start = time.time()

try:
    with engine.begin() as conn:
        for stmt in FULL_DDL.split(';'):
            stmt = stmt.strip()
            if stmt:
                conn.execute(text(stmt + ';'))
    elapsed = time.time() - start
    print(f'DDL berhasil dieksekusi dalam {elapsed:.2f} detik')
except Exception as e:
    print(f'ERROR saat DDL: {e}')
# Out:
# >>> Mengeksekusi DDL...
# DDL berhasil dieksekusi dalam 8.45 detik

# %% [markdown]
# ### 3.2 Insert Data ke Tabel

# %%
tables_to_load = [
    ('dim_country', dim_country),
    ('dim_year', dim_year),
    ('dim_cause', dim_cause),
    ('dim_sex', dim_sex),
    ('fact_mortality', fact_mortality),
    ('fact_life_expectancy', fact_life),
]

for name, df in tables_to_load:
    start = time.time()
    try:
        df.to_sql(name, engine, if_exists='append', index=False, method='multi', chunksize=1000)
        elapsed = time.time() - start
        print(f'OK {name}: {len(df):,} rows dalam {elapsed:.2f}s')
    except Exception as e:
        print(f'ERROR {name}: {e}')
# Out:
# ERROR dim_country: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "dim_country_pkey"
# DETAIL:  Key (country_id)=(1) already exists.
#
# [SQL: INSERT INTO dim_country (country_code, country_name, m49_code, country_id) VALUES (%(country_code_m0)s, %(country_name_m0)s, %(m49_code_m0)s, %(country_id_m0)s), (%(country_code_m1)s, %(country_name_m1)s, %(m49_code_m1)s, %(country_id_m1)s), (%(country_code_m2)s, %(country_name_m2)s, %(m49_code_m2)s, %(country_id_m2)s), (%(country_code_m3)s, %(country_name_m3)s, %(m49_code_m3)s, %(country_id_m3)s), (%(country_code_m4)s, %(country_name_m4)s, %(m49_code_m4)s, %(country_id_m4)s), (%(country_code_m5)s, %(country_name_m5)s, %(m49_code_m5)s, %(country_id_m5)s), (%(country_code_m6)s, %(country_name_m6)s, %(m49_code_m6)s, %(country_id_m6)s), (%(country_code_m7)s, %(country_name_m7)s, %(m49_code_m7)s, %(country_id_m7)s), (%(country_code_m8)s, %(country_name_m8)s, %(m49_code_m8)s, %(country_id_m8)s), (%(country_code_m9)s, %(country_name_m9)s, %(m49_code_m9)s, %(country_id_m9)s), (%(country_code_m10)s, %(country_name_m10)s, %(m49_code_m10)s, %(country_id_m10)s), (%(country_code_m11)s, %(country_name_m11)s, %(m49_code_m11)s, %(country_id_m11)s), (%(country_code_m12)s, %(country_name_m12)s, %(m49_code_m12)s, %(country_id_m12)s), (%(country_code_m13)s, %(country_name_m13)s, %(m49_code_m13)s, %(country_id_m13)s), (%(country_code_m14)s, %(country_name_m14)s, %(m49_code_m14)s, %(country_id_m14)s), (%(country_code_m15)s, %(country_name_m15)s, %(m49_code_m15)s, %(country_id_m15)s), (%(country_code_m16)s, %(country_name_m16)s, %(m49_code_m16)s, %(country_id_m16)s), (%(country_code_m17)s, %(country_name_m17)s, %(m49_code_m17)s, %(country_id_m17)s), (%(country_code_m18)s, %(country_name_m18)s, %(m49_code_m18)s, %(country_id_m18)s), (%(country_code_m19)s, %(country_name_m19)s, %(m49_code_m19)s, %(country_id_m19)s), (%(country_code_m20)s, %(country_name_m20)s, %(m49_code_m20)s, %(country_id_m20)s), (%(country_code_m21)s, %(country_name_m21)s, %(m49_code_m21)s, %(country_id_m21)s), (%(country_code_m22)s, %(country_name_m22)s, %(m49_code_m22)s, %(country_id_m22)s), (%(country_code_m23)s, %(country_name_m23)s, %(m49_code_m23)s, %(country_id_m23)s), (%(country_code_m24)s, %(country_name_m24)s, %(m49_code_m24)s, %(country_id_m24)s), (%(country_code_m25)s, %(country_name_m25)s, %(m49_code_m25)s, %(country_id_m25)s), (%(country_code_m26)s, %(country_name_m26)s, %(m49_code_m26)s, %(country_id_m26)s), (%(country_code_m27)s, %(country_name_m27)s, %(m49_code_m27)s, %(country_id_m27)s), (%(country_code_m28)s, %(country_name_m28)s, %(m49_code_m28)s, %(country_id_m28)s), (%(country_code_m29)s, %(country_name_m29)s, %(m49_code_m29)s, %(country_id_m29)s), (%(country_code_m30)s, %(country_name_m30)s, %(m49_code_m30)s, %(country_id_m30)s), (%(country_code_m31)s, %(country_name_m31)s, %(m49_code_m31)s, %(country_id_m31)s), (%(country_code_m32)s, %(country_name_m32)s, %(m49_code_m32)s, %(country_id_m32)s), (%(country_code_m33)s, %(country_name_m33)s, %(m49_code_m33)s, %(country_id_m33)s), (%(country_code_m34)s, %(country_name_m34)s, %(m49_code_m34)s, %(country_id_m34)s), (%(country_code_m35)s, %(country_name_m35)s, %(m49_code_m35)s, %(country_id_m35)s), (%(country_code_m36)s, %(country_name_m36)s, %(m49_code_m36)s, %(country_id_m36)s), (%(country_code_m37)s, %(country_name_m37)s, %(m49_code_m37)s, %(country_id_m37)s), (%(country_code_m38)s, %(country_name_m38)s, %(m49_code_m38)s, %(country_id_m38)s), (%(country_code_m39)s, %(country_name_m39)s, %(m49_code_m39)s, %(country_id_m39)s), (%(country_code_m40)s, %(country_name_m40)s, %(m49_code_m40)s, %(country_id_m40)s), (%(country_code_m41)s, %(country_name_m41)s, %(m49_code_m41)s, %(country_id_m41)s), (%(country_code_m42)s, %(country_name_m42)s, %(m49_code_m42)s, %(country_id_m42)s), (%(country_code_m43)s, %(country_name_m43)s, %(m49_code_m43)s, %(country_id_m43)s), (%(country_code_m44)s, %(country_name_m44)s, %(m49_code_m44)s, %(country_id_m44)s), (%(country_code_m45)s, %(country_name_m45)s, %(m49_code_m45)s, %(country_id_m45)s), (%(country_code_m46)s, %(country_name_m46)s, %(m49_code_m46)s, %(country_id_m46)s), (%(c ...
# [parameters: {'country_code_m0': 'AFG', 'country_name_m0': 'Afghanistan', 'm49_code_m0': '004', 'country_id_m0': 1, 'country_code_m1': 'AGO', 'country_name_m1': 'Angola', 'm49_code_m1': '024', 'country_id_m1': 2, 'country_code_m2': 'ALB', 'country_name_m2': 'Albania', 'm49_code_m2': '008', 'country_id_m2': 3, 'country_code_m3': 'ARE', 'country_name_m3': 'United Arab Emirates', 'm49_code_m3': '784', 'country_id_m3': 4, 'country_code_m4': 'ARG', 'country_name_m4': 'Argentina', 'm49_code_m4': '032', 'country_id_m4': 5, 'country_code_m5': 'ARM', 'country_name_m5': 'Armenia', 'm49_code_m5': '051', 'country_id_m5': 6, 'country_code_m6': 'ATG', 'country_name_m6': 'Antigua and Barbuda', 'm49_code_m6': '028', 'country_id_m6': 7, 'country_code_m7': 'AUS', 'country_name_m7': 'Australia', 'm49_code_m7': '036', 'country_id_m7': 8, 'country_code_m8': 'AUT', 'country_name_m8': 'Austria', 'm49_code_m8': '040', 'country_id_m8': 9, 'country_code_m9': 'AZE', 'country_name_m9': 'Azerbaijan', 'm49_code_m9': '031', 'country_id_m9': 10, 'country_code_m10': 'BDI', 'country_name_m10': 'Burundi', 'm49_code_m10': '108', 'country_id_m10': 11, 'country_code_m11': 'BEL', 'country_name_m11': 'Belgium', 'm49_code_m11': '056', 'country_id_m11': 12, 'country_code_m12': 'BEN', 'country_name_m12': 'Benin' ... 632 parameters truncated ... 'm49_code_m170': '804', 'country_id_m170': 171, 'country_code_m171': 'URY', 'country_name_m171': 'Uruguay', 'm49_code_m171': '858', 'country_id_m171': 172, 'country_code_m172': 'USA', 'country_name_m172': 'United States', 'm49_code_m172': '840', 'country_id_m172': 173, 'country_code_m173': 'UZB', 'country_name_m173': 'Uzbekistan', 'm49_code_m173': '860', 'country_id_m173': 174, 'country_code_m174': 'VCT', 'country_name_m174': 'Saint Vincent and the Grenadines', 'm49_code_m174': '670', 'country_id_m174': 175, 'country_code_m175': 'VEN', 'country_name_m175': 'Venezuela, Bolivarian Republic of', 'm49_code_m175': '862', 'country_id_m175': 176, 'country_code_m176': 'VNM', 'country_name_m176': 'Viet Nam', 'm49_code_m176': '704', 'country_id_m176': 177, 'country_code_m177': 'VUT', 'country_name_m177': 'Vanuatu', 'm49_code_m177': '548', 'country_id_m177': 178, 'country_code_m178': 'WSM', 'country_name_m178': 'Samoa', 'm49_code_m178': '882', 'country_id_m178': 179, 'country_code_m179': 'YEM', 'country_name_m179': 'Yemen', 'm49_code_m179': '887', 'country_id_m179': 180, 'country_code_m180': 'ZAF', 'country_name_m180': 'South Africa', 'm49_code_m180': '710', 'country_id_m180': 181, 'country_code_m181': 'ZMB', 'country_name_m181': 'Zambia', 'm49_code_m181': '894', 'country_id_m181': 182, 'country_code_m182': 'ZWE', 'country_name_m182': 'Zimbabwe', 'm49_code_m182': '716', 'country_id_m182': 183}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ERROR dim_year: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "dim_year_pkey"
# DETAIL:  Key (year_id)=(1) already exists.
#
# [SQL: INSERT INTO dim_year (year, year_id) VALUES (%(year_m0)s, %(year_id_m0)s), (%(year_m1)s, %(year_id_m1)s), (%(year_m2)s, %(year_id_m2)s), (%(year_m3)s, %(year_id_m3)s), (%(year_m4)s, %(year_id_m4)s), (%(year_m5)s, %(year_id_m5)s), (%(year_m6)s, %(year_id_m6)s), (%(year_m7)s, %(year_id_m7)s), (%(year_m8)s, %(year_id_m8)s), (%(year_m9)s, %(year_id_m9)s), (%(year_m10)s, %(year_id_m10)s), (%(year_m11)s, %(year_id_m11)s), (%(year_m12)s, %(year_id_m12)s), (%(year_m13)s, %(year_id_m13)s), (%(year_m14)s, %(year_id_m14)s), (%(year_m15)s, %(year_id_m15)s), (%(year_m16)s, %(year_id_m16)s), (%(year_m17)s, %(year_id_m17)s), (%(year_m18)s, %(year_id_m18)s), (%(year_m19)s, %(year_id_m19)s), (%(year_m20)s, %(year_id_m20)s), (%(year_m21)s, %(year_id_m21)s)]
# [parameters: {'year_m0': 2000, 'year_id_m0': 1, 'year_m1': 2001, 'year_id_m1': 2, 'year_m2': 2002, 'year_id_m2': 3, 'year_m3': 2003, 'year_id_m3': 4, 'year_m4': 2004, 'year_id_m4': 5, 'year_m5': 2005, 'year_id_m5': 6, 'year_m6': 2006, 'year_id_m6': 7, 'year_m7': 2007, 'year_id_m7': 8, 'year_m8': 2008, 'year_id_m8': 9, 'year_m9': 2009, 'year_id_m9': 10, 'year_m10': 2010, 'year_id_m10': 11, 'year_m11': 2011, 'year_id_m11': 12, 'year_m12': 2012, 'year_id_m12': 13, 'year_m13': 2013, 'year_id_m13': 14, 'year_m14': 2014, 'year_id_m14': 15, 'year_m15': 2015, 'year_id_m15': 16, 'year_m16': 2016, 'year_id_m16': 17, 'year_m17': 2017, 'year_id_m17': 18, 'year_m18': 2018, 'year_id_m18': 19, 'year_m19': 2019, 'year_id_m19': 20, 'year_m20': 2020, 'year_id_m20': 21, 'year_m21': 2021, 'year_id_m21': 22}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ERROR dim_cause: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "dim_cause_pkey"
# DETAIL:  Key (cause_id)=(1) already exists.
#
# [SQL: INSERT INTO dim_cause (cause_id, cause_name, cause_category) VALUES (%(cause_id_m0)s, %(cause_name_m0)s, %(cause_category_m0)s), (%(cause_id_m1)s, %(cause_name_m1)s, %(cause_category_m1)s), (%(cause_id_m2)s, %(cause_name_m2)s, %(cause_category_m2)s), (%(cause_id_m3)s, %(cause_name_m3)s, %(cause_category_m3)s), (%(cause_id_m4)s, %(cause_name_m4)s, %(cause_category_m4)s), (%(cause_id_m5)s, %(cause_name_m5)s, %(cause_category_m5)s), (%(cause_id_m6)s, %(cause_name_m6)s, %(cause_category_m6)s), (%(cause_id_m7)s, %(cause_name_m7)s, %(cause_category_m7)s), (%(cause_id_m8)s, %(cause_name_m8)s, %(cause_category_m8)s), (%(cause_id_m9)s, %(cause_name_m9)s, %(cause_category_m9)s), (%(cause_id_m10)s, %(cause_name_m10)s, %(cause_category_m10)s), (%(cause_id_m11)s, %(cause_name_m11)s, %(cause_category_m11)s), (%(cause_id_m12)s, %(cause_name_m12)s, %(cause_category_m12)s), (%(cause_id_m13)s, %(cause_name_m13)s, %(cause_category_m13)s), (%(cause_id_m14)s, %(cause_name_m14)s, %(cause_category_m14)s), (%(cause_id_m15)s, %(cause_name_m15)s, %(cause_category_m15)s), (%(cause_id_m16)s, %(cause_name_m16)s, %(cause_category_m16)s), (%(cause_id_m17)s, %(cause_name_m17)s, %(cause_category_m17)s), (%(cause_id_m18)s, %(cause_name_m18)s, %(cause_category_m18)s), (%(cause_id_m19)s, %(cause_name_m19)s, %(cause_category_m19)s), (%(cause_id_m20)s, %(cause_name_m20)s, %(cause_category_m20)s), (%(cause_id_m21)s, %(cause_name_m21)s, %(cause_category_m21)s), (%(cause_id_m22)s, %(cause_name_m22)s, %(cause_category_m22)s), (%(cause_id_m23)s, %(cause_name_m23)s, %(cause_category_m23)s), (%(cause_id_m24)s, %(cause_name_m24)s, %(cause_category_m24)s), (%(cause_id_m25)s, %(cause_name_m25)s, %(cause_category_m25)s), (%(cause_id_m26)s, %(cause_name_m26)s, %(cause_category_m26)s), (%(cause_id_m27)s, %(cause_name_m27)s, %(cause_category_m27)s), (%(cause_id_m28)s, %(cause_name_m28)s, %(cause_category_m28)s), (%(cause_id_m29)s, %(cause_name_m29)s, %(cause_category_m29)s), (%(cause_id_m30)s, %(cause_name_m30)s, %(cause_category_m30)s), (%(cause_id_m31)s, %(cause_name_m31)s, %(cause_category_m31)s), (%(cause_id_m32)s, %(cause_name_m32)s, %(cause_category_m32)s), (%(cause_id_m33)s, %(cause_name_m33)s, %(cause_category_m33)s), (%(cause_id_m34)s, %(cause_name_m34)s, %(cause_category_m34)s), (%(cause_id_m35)s, %(cause_name_m35)s, %(cause_category_m35)s), (%(cause_id_m36)s, %(cause_name_m36)s, %(cause_category_m36)s), (%(cause_id_m37)s, %(cause_name_m37)s, %(cause_category_m37)s), (%(cause_id_m38)s, %(cause_name_m38)s, %(cause_category_m38)s), (%(cause_id_m39)s, %(cause_name_m39)s, %(cause_category_m39)s), (%(cause_id_m40)s, %(cause_name_m40)s, %(cause_category_m40)s), (%(cause_id_m41)s, %(cause_name_m41)s, %(cause_category_m41)s), (%(cause_id_m42)s, %(cause_name_m42)s, %(cause_category_m42)s), (%(cause_id_m43)s, %(cause_name_m43)s, %(cause_category_m43)s), (%(cause_id_m44)s, %(cause_name_m44)s, %(cause_category_m44)s), (%(cause_id_m45)s, %(cause_name_m45)s, %(cause_category_m45)s), (%(cause_id_m46)s, %(cause_name_m46)s, %(cause_category_m46)s), (%(cause_id_m47)s, %(cause_name_m47)s, %(cause_category_m47)s), (%(cause_id_m48)s, %(cause_name_m48)s, %(cause_category_m48)s), (%(cause_id_m49)s, %(cause_name_m49)s, %(cause_category_m49)s), (%(cause_id_m50)s, %(cause_name_m50)s, %(cause_category_m50)s), (%(cause_id_m51)s, %(cause_name_m51)s, %(cause_category_m51)s), (%(cause_id_m52)s, %(cause_name_m52)s, %(cause_category_m52)s), (%(cause_id_m53)s, %(cause_name_m53)s, %(cause_category_m53)s), (%(cause_id_m54)s, %(cause_name_m54)s, %(cause_category_m54)s), (%(cause_id_m55)s, %(cause_name_m55)s, %(cause_category_m55)s), (%(cause_id_m56)s, %(cause_name_m56)s, %(cause_category_m56)s), (%(cause_id_m57)s, %(cause_name_m57)s, %(cause_category_m57)s), (%(cause_id_m58)s, %(cause_name_m58)s, %(cause_category_m58)s), (%(cause_id_m59)s, %(cause_name_m59)s, %(cause_category_m59)s), (%(cause_id_m60)s, %(cause_name_m60)s, %(cause_category_m60)s), (%(cause_id_m61)s, %(cause_name_m61)s, %(cause_categ ...
# [parameters: {'cause_id_m0': 1, 'cause_name_m0': 'Acute hepatitis A', 'cause_category_m0': 'Communicable', 'cause_id_m1': 2, 'cause_name_m1': 'Acute hepatitis B', 'cause_category_m1': 'Communicable', 'cause_id_m2': 3, 'cause_name_m2': 'Acute hepatitis C', 'cause_category_m2': 'Communicable', 'cause_id_m3': 4, 'cause_name_m3': 'Acute hepatitis E', 'cause_category_m3': 'Communicable', 'cause_id_m4': 5, 'cause_name_m4': 'African trypanosomiasis', 'cause_category_m4': 'Communicable', 'cause_id_m5': 6, 'cause_name_m5': 'Alcohol use disorders', 'cause_category_m5': 'Non-communicable', 'cause_id_m6': 7, 'cause_name_m6': 'Alzheimer disease and other dementias', 'cause_category_m6': 'Non-communicable', 'cause_id_m7': 8, 'cause_name_m7': 'Anxiety disorders', 'cause_category_m7': 'Non-communicable', 'cause_id_m8': 9, 'cause_name_m8': 'Appendicitis', 'cause_category_m8': 'Non-communicable', 'cause_id_m9': 10, 'cause_name_m9': 'Ascariasis', 'cause_category_m9': 'Communicable', 'cause_id_m10': 11, 'cause_name_m10': 'Asthma', 'cause_category_m10': 'Non-communicable', 'cause_id_m11': 12, 'cause_name_m11': 'Autism and Asperger syndrome', 'cause_category_m11': 'Non-communicable', 'cause_id_m12': 13, 'cause_name_m12': 'Back and neck pain', 'cause_category_m12': 'Non-communicable', 'cause_id_m13': 14, 'cause_name_m13': 'Benign prostatic hyperplasia', 'cause_category_m13': 'Non-communicable', 'cause_id_m14': 15, 'cause_name_m14': 'Bipolar disorder', 'cause_category_m14': 'Non-communicable', 'cause_id_m15': 16, 'cause_name_m15': 'Birth asphyxia and birth trauma', 'cause_category_m15': 'Communicable', 'cause_id_m16': 17, 'cause_name_m16': 'Bladder cancer' ... 302 parameters truncated ... 'cause_name_m117': 'Sudden infant death syndrome', 'cause_category_m117': 'Non-communicable', 'cause_id_m118': 119, 'cause_name_m118': 'Syphilis', 'cause_category_m118': 'Communicable', 'cause_id_m119': 120, 'cause_name_m119': 'Testicular cancer', 'cause_category_m119': 'Non-communicable', 'cause_id_m120': 121, 'cause_name_m120': 'Tetanus', 'cause_category_m120': 'Communicable', 'cause_id_m121': 122, 'cause_name_m121': 'Thalassaemias', 'cause_category_m121': 'Non-communicable', 'cause_id_m122': 123, 'cause_name_m122': 'Thyroid cancer', 'cause_category_m122': 'Non-communicable', 'cause_id_m123': 124, 'cause_name_m123': 'Trachea, bronchus, lung cancers', 'cause_category_m123': 'Non-communicable', 'cause_id_m124': 125, 'cause_name_m124': 'Trachoma', 'cause_category_m124': 'Communicable', 'cause_id_m125': 126, 'cause_name_m125': 'Trichomoniasis', 'cause_category_m125': 'Communicable', 'cause_id_m126': 127, 'cause_name_m126': 'Trichuriasis', 'cause_category_m126': 'Communicable', 'cause_id_m127': 128, 'cause_name_m127': 'Tuberculosis', 'cause_category_m127': 'Communicable', 'cause_id_m128': 129, 'cause_name_m128': 'Uncorrected refractive errors', 'cause_category_m128': 'Non-communicable', 'cause_id_m129': 130, 'cause_name_m129': 'Upper respiratory infections', 'cause_category_m129': 'Communicable', 'cause_id_m130': 131, 'cause_name_m130': 'Urolithiasis', 'cause_category_m130': 'Non-communicable', 'cause_id_m131': 132, 'cause_name_m131': 'Vitamin A deficiency', 'cause_category_m131': 'Communicable', 'cause_id_m132': 133, 'cause_name_m132': 'Whooping cough', 'cause_category_m132': 'Communicable', 'cause_id_m133': 134, 'cause_name_m133': 'Yellow fever', 'cause_category_m133': 'Communicable'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ERROR dim_sex: (psycopg2.errors.StringDataRightTruncation) value too long for type character varying(4)
#
# [SQL: INSERT INTO dim_sex (sex_id, sex_code, sex_name) VALUES (%(sex_id_m0)s, %(sex_code_m0)s, %(sex_name_m0)s), (%(sex_id_m1)s, %(sex_code_m1)s, %(sex_name_m1)s), (%(sex_id_m2)s, %(sex_code_m2)s, %(sex_name_m2)s), (%(sex_id_m3)s, %(sex_code_m3)s, %(sex_name_m3)s)]
# [parameters: {'sex_id_m0': 1, 'sex_code_m0': 'BTSX', 'sex_name_m0': 'Both sexes', 'sex_id_m1': 2, 'sex_code_m1': 'FMLE', 'sex_name_m1': 'Female', 'sex_id_m2': 3, 'sex_code_m2': 'MLE', 'sex_name_m2': 'Male', 'sex_id_m3': 4, 'sex_code_m3': 'TOTAL', 'sex_name_m3': 'Total'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# ERROR fact_mortality: (psycopg2.errors.CheckViolation) no partition of relation "fact_mortality" found for row
# DETAIL:  Partition key of the failing row contains (year_id) = (22).
#
# [SQL: INSERT INTO fact_mortality (country_id, year_id, cause_id, sex_id, death_rate) VALUES (%(country_id_m0)s, %(year_id_m0)s, %(cause_id_m0)s, %(sex_id_m0)s, %(death_rate_m0)s), (%(country_id_m1)s, %(year_id_m1)s, %(cause_id_m1)s, %(sex_id_m1)s, %(death_rate_m1)s), (%(country_id_m2)s, %(year_id_m2)s, %(cause_id_m2)s, %(sex_id_m2)s, %(death_rate_m2)s), (%(country_id_m3)s, %(year_id_m3)s, %(cause_id_m3)s, %(sex_id_m3)s, %(death_rate_m3)s), (%(country_id_m4)s, %(year_id_m4)s, %(cause_id_m4)s, %(sex_id_m4)s, %(death_rate_m4)s), (%(country_id_m5)s, %(year_id_m5)s, %(cause_id_m5)s, %(sex_id_m5)s, %(death_rate_m5)s), (%(country_id_m6)s, %(year_id_m6)s, %(cause_id_m6)s, %(sex_id_m6)s, %(death_rate_m6)s), (%(country_id_m7)s, %(year_id_m7)s, %(cause_id_m7)s, %(sex_id_m7)s, %(death_rate_m7)s), (%(country_id_m8)s, %(year_id_m8)s, %(cause_id_m8)s, %(sex_id_m8)s, %(death_rate_m8)s), (%(country_id_m9)s, %(year_id_m9)s, %(cause_id_m9)s, %(sex_id_m9)s, %(death_rate_m9)s), (%(country_id_m10)s, %(year_id_m10)s, %(cause_id_m10)s, %(sex_id_m10)s, %(death_rate_m10)s), (%(country_id_m11)s, %(year_id_m11)s, %(cause_id_m11)s, %(sex_id_m11)s, %(death_rate_m11)s), (%(country_id_m12)s, %(year_id_m12)s, %(cause_id_m12)s, %(sex_id_m12)s, %(death_rate_m12)s), (%(country_id_m13)s, %(year_id_m13)s, %(cause_id_m13)s, %(sex_id_m13)s, %(death_rate_m13)s), (%(country_id_m14)s, %(year_id_m14)s, %(cause_id_m14)s, %(sex_id_m14)s, %(death_rate_m14)s), (%(country_id_m15)s, %(year_id_m15)s, %(cause_id_m15)s, %(sex_id_m15)s, %(death_rate_m15)s), (%(country_id_m16)s, %(year_id_m16)s, %(cause_id_m16)s, %(sex_id_m16)s, %(death_rate_m16)s), (%(country_id_m17)s, %(year_id_m17)s, %(cause_id_m17)s, %(sex_id_m17)s, %(death_rate_m17)s), (%(country_id_m18)s, %(year_id_m18)s, %(cause_id_m18)s, %(sex_id_m18)s, %(death_rate_m18)s), (%(country_id_m19)s, %(year_id_m19)s, %(cause_id_m19)s, %(sex_id_m19)s, %(death_rate_m19)s), (%(country_id_m20)s, %(year_id_m20)s, %(cause_id_m20)s, %(sex_id_m20)s, %(death_rate_m20)s), (%(country_id_m21)s, %(year_id_m21)s, %(cause_id_m21)s, %(sex_id_m21)s, %(death_rate_m21)s), (%(country_id_m22)s, %(year_id_m22)s, %(cause_id_m22)s, %(sex_id_m22)s, %(death_rate_m22)s), (%(country_id_m23)s, %(year_id_m23)s, %(cause_id_m23)s, %(sex_id_m23)s, %(death_rate_m23)s), (%(country_id_m24)s, %(year_id_m24)s, %(cause_id_m24)s, %(sex_id_m24)s, %(death_rate_m24)s), (%(country_id_m25)s, %(year_id_m25)s, %(cause_id_m25)s, %(sex_id_m25)s, %(death_rate_m25)s), (%(country_id_m26)s, %(year_id_m26)s, %(cause_id_m26)s, %(sex_id_m26)s, %(death_rate_m26)s), (%(country_id_m27)s, %(year_id_m27)s, %(cause_id_m27)s, %(sex_id_m27)s, %(death_rate_m27)s), (%(country_id_m28)s, %(year_id_m28)s, %(cause_id_m28)s, %(sex_id_m28)s, %(death_rate_m28)s), (%(country_id_m29)s, %(year_id_m29)s, %(cause_id_m29)s, %(sex_id_m29)s, %(death_rate_m29)s), (%(country_id_m30)s, %(year_id_m30)s, %(cause_id_m30)s, %(sex_id_m30)s, %(death_rate_m30)s), (%(country_id_m31)s, %(year_id_m31)s, %(cause_id_m31)s, %(sex_id_m31)s, %(death_rate_m31)s), (%(country_id_m32)s, %(year_id_m32)s, %(cause_id_m32)s, %(sex_id_m32)s, %(death_rate_m32)s), (%(country_id_m33)s, %(year_id_m33)s, %(cause_id_m33)s, %(sex_id_m33)s, %(death_rate_m33)s), (%(country_id_m34)s, %(year_id_m34)s, %(cause_id_m34)s, %(sex_id_m34)s, %(death_rate_m34)s), (%(country_id_m35)s, %(year_id_m35)s, %(cause_id_m35)s, %(sex_id_m35)s, %(death_rate_m35)s), (%(country_id_m36)s, %(year_id_m36)s, %(cause_id_m36)s, %(sex_id_m36)s, %(death_rate_m36)s), (%(country_id_m37)s, %(year_id_m37)s, %(cause_id_m37)s, %(sex_id_m37)s, %(death_rate_m37)s), (%(country_id_m38)s, %(year_id_m38)s, %(cause_id_m38)s, %(sex_id_m38)s, %(death_rate_m38)s), (%(country_id_m39)s, %(year_id_m39)s, %(cause_id_m39)s, %(sex_id_m39)s, %(death_rate_m39)s), (%(country_id_m40)s, %(year_id_m40)s, %(cause_id_m40)s, %(sex_id_m40)s, %(death_rate_m40)s), (%(country_id_m41)s, %(year_id_m41)s, %(cause_id_m41)s, %(sex_id_m41)s, %(death_rate_m41)s), (%(country_id_m42)s, %(year_id_m42)s, %(cause_id_m42 ...
# [parameters: {'country_id_m0': 1, 'year_id_m0': 22, 'cause_id_m0': 119, 'sex_id_m0': 1, 'death_rate_m0': 1.46, 'country_id_m1': 1, 'year_id_m1': 22, 'cause_id_m1': 52, 'sex_id_m1': 1, 'death_rate_m1': 0.0, 'country_id_m2': 1, 'year_id_m2': 22, 'cause_id_m2': 38, 'sex_id_m2': 1, 'death_rate_m2': 0.11, 'country_id_m3': 1, 'year_id_m3': 22, 'cause_id_m3': 5, 'sex_id_m3': 1, 'death_rate_m3': 0.0, 'country_id_m4': 1, 'year_id_m4': 22, 'cause_id_m4': 34, 'sex_id_m4': 1, 'death_rate_m4': 0.0, 'country_id_m5': 1, 'year_id_m5': 22, 'cause_id_m5': 107, 'sex_id_m5': 1, 'death_rate_m5': 0.17, 'country_id_m6': 1, 'year_id_m6': 22, 'cause_id_m6': 74, 'sex_id_m6': 1, 'death_rate_m6': 33.11, 'country_id_m7': 1, 'year_id_m7': 22, 'cause_id_m7': 132, 'sex_id_m7': 1, 'death_rate_m7': 0.0, 'country_id_m8': 1, 'year_id_m8': 22, 'cause_id_m8': 73, 'sex_id_m8': 1, 'death_rate_m8': 1.99, 'country_id_m9': 1, 'year_id_m9': 22, 'cause_id_m9': 17, 'sex_id_m9': 1, 'death_rate_m9': 0.58 ... 4900 parameters truncated ... 'country_id_m990': 8, 'year_id_m990': 22, 'cause_id_m990': 120, 'sex_id_m990': 1, 'death_rate_m990': 0.15, 'country_id_m991': 8, 'year_id_m991': 22, 'cause_id_m991': 67, 'sex_id_m991': 1, 'death_rate_m991': 4.48, 'country_id_m992': 8, 'year_id_m992': 22, 'cause_id_m992': 18, 'sex_id_m992': 1, 'death_rate_m992': 6.85, 'country_id_m993': 8, 'year_id_m993': 22, 'cause_id_m993': 114, 'sex_id_m993': 1, 'death_rate_m993': 0.0, 'country_id_m994': 8, 'year_id_m994': 22, 'cause_id_m994': 40, 'sex_id_m994': 1, 'death_rate_m994': 4.92, 'country_id_m995': 8, 'year_id_m995': 22, 'cause_id_m995': 101, 'sex_id_m995': 1, 'death_rate_m995': 9.16, 'country_id_m996': 8, 'year_id_m996': 22, 'cause_id_m996': 129, 'sex_id_m996': 1, 'death_rate_m996': 0.0, 'country_id_m997': 8, 'year_id_m997': 22, 'cause_id_m997': 117, 'sex_id_m997': 1, 'death_rate_m997': 40.32, 'country_id_m998': 8, 'year_id_m998': 22, 'cause_id_m998': 28, 'sex_id_m998': 1, 'death_rate_m998': 6.95, 'country_id_m999': 8, 'year_id_m999': 22, 'cause_id_m999': 56, 'sex_id_m999': 1, 'death_rate_m999': 0.0}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ERROR fact_life_expectancy: (psycopg2.errors.ForeignKeyViolation) insert or update on table "fact_life_2000" violates foreign key constraint "fact_life_expectancy_sex_id_fkey"
# DETAIL:  Key (sex_id)=(2) is not present in table "dim_sex".
#
# [SQL: INSERT INTO fact_life_expectancy (country_id, year_id, sex_id, life_expectancy, healthy_life_expectancy) VALUES (%(country_id_m0)s, %(year_id_m0)s, %(sex_id_m0)s, %(life_expectancy_m0)s, %(healthy_life_expectancy_m0)s), (%(country_id_m1)s, %(year_id_m1)s, %(sex_id_m1)s, %(life_expectancy_m1)s, %(healthy_life_expectancy_m1)s), (%(country_id_m2)s, %(year_id_m2)s, %(sex_id_m2)s, %(life_expectancy_m2)s, %(healthy_life_expectancy_m2)s), (%(country_id_m3)s, %(year_id_m3)s, %(sex_id_m3)s, %(life_expectancy_m3)s, %(healthy_life_expectancy_m3)s), (%(country_id_m4)s, %(year_id_m4)s, %(sex_id_m4)s, %(life_expectancy_m4)s, %(healthy_life_expectancy_m4)s), (%(country_id_m5)s, %(year_id_m5)s, %(sex_id_m5)s, %(life_expectancy_m5)s, %(healthy_life_expectancy_m5)s), (%(country_id_m6)s, %(year_id_m6)s, %(sex_id_m6)s, %(life_expectancy_m6)s, %(healthy_life_expectancy_m6)s), (%(country_id_m7)s, %(year_id_m7)s, %(sex_id_m7)s, %(life_expectancy_m7)s, %(healthy_life_expectancy_m7)s), (%(country_id_m8)s, %(year_id_m8)s, %(sex_id_m8)s, %(life_expectancy_m8)s, %(healthy_life_expectancy_m8)s), (%(country_id_m9)s, %(year_id_m9)s, %(sex_id_m9)s, %(life_expectancy_m9)s, %(healthy_life_expectancy_m9)s), (%(country_id_m10)s, %(year_id_m10)s, %(sex_id_m10)s, %(life_expectancy_m10)s, %(healthy_life_expectancy_m10)s), (%(country_id_m11)s, %(year_id_m11)s, %(sex_id_m11)s, %(life_expectancy_m11)s, %(healthy_life_expectancy_m11)s), (%(country_id_m12)s, %(year_id_m12)s, %(sex_id_m12)s, %(life_expectancy_m12)s, %(healthy_life_expectancy_m12)s), (%(country_id_m13)s, %(year_id_m13)s, %(sex_id_m13)s, %(life_expectancy_m13)s, %(healthy_life_expectancy_m13)s), (%(country_id_m14)s, %(year_id_m14)s, %(sex_id_m14)s, %(life_expectancy_m14)s, %(healthy_life_expectancy_m14)s), (%(country_id_m15)s, %(year_id_m15)s, %(sex_id_m15)s, %(life_expectancy_m15)s, %(healthy_life_expectancy_m15)s), (%(country_id_m16)s, %(year_id_m16)s, %(sex_id_m16)s, %(life_expectancy_m16)s, %(healthy_life_expectancy_m16)s), (%(country_id_m17)s, %(year_id_m17)s, %(sex_id_m17)s, %(life_expectancy_m17)s, %(healthy_life_expectancy_m17)s), (%(country_id_m18)s, %(year_id_m18)s, %(sex_id_m18)s, %(life_expectancy_m18)s, %(healthy_life_expectancy_m18)s), (%(country_id_m19)s, %(year_id_m19)s, %(sex_id_m19)s, %(life_expectancy_m19)s, %(healthy_life_expectancy_m19)s), (%(country_id_m20)s, %(year_id_m20)s, %(sex_id_m20)s, %(life_expectancy_m20)s, %(healthy_life_expectancy_m20)s), (%(country_id_m21)s, %(year_id_m21)s, %(sex_id_m21)s, %(life_expectancy_m21)s, %(healthy_life_expectancy_m21)s), (%(country_id_m22)s, %(year_id_m22)s, %(sex_id_m22)s, %(life_expectancy_m22)s, %(healthy_life_expectancy_m22)s), (%(country_id_m23)s, %(year_id_m23)s, %(sex_id_m23)s, %(life_expectancy_m23)s, %(healthy_life_expectancy_m23)s), (%(country_id_m24)s, %(year_id_m24)s, %(sex_id_m24)s, %(life_expectancy_m24)s, %(healthy_life_expectancy_m24)s), (%(country_id_m25)s, %(year_id_m25)s, %(sex_id_m25)s, %(life_expectancy_m25)s, %(healthy_life_expectancy_m25)s), (%(country_id_m26)s, %(year_id_m26)s, %(sex_id_m26)s, %(life_expectancy_m26)s, %(healthy_life_expectancy_m26)s), (%(country_id_m27)s, %(year_id_m27)s, %(sex_id_m27)s, %(life_expectancy_m27)s, %(healthy_life_expectancy_m27)s), (%(country_id_m28)s, %(year_id_m28)s, %(sex_id_m28)s, %(life_expectancy_m28)s, %(healthy_life_expectancy_m28)s), (%(country_id_m29)s, %(year_id_m29)s, %(sex_id_m29)s, %(life_expectancy_m29)s, %(healthy_life_expectancy_m29)s), (%(country_id_m30)s, %(year_id_m30)s, %(sex_id_m30)s, %(life_expectancy_m30)s, %(healthy_life_expectancy_m30)s), (%(country_id_m31)s, %(year_id_m31)s, %(sex_id_m31)s, %(life_expectancy_m31)s, %(healthy_life_expectancy_m31)s), (%(country_id_m32)s, %(year_id_m32)s, %(sex_id_m32)s, %(life_expectancy_m32)s, %(healthy_life_expectancy_m32)s), (%(country_id_m33)s, %(year_id_m33)s, %(sex_id_m33)s, %(life_expectancy_m33)s, %(healthy_life_expectancy_m33)s), (%(country_id_m34)s, %(year_id_m34)s, %(sex_id_m34)s, %(life_expectancy_m34)s, %(healthy_l ...
# [parameters: {'country_id_m0': 1, 'year_id_m0': 1, 'sex_id_m0': 2, 'life_expectancy_m0': 54.42957895, 'healthy_life_expectancy_m0': 46.15485101, 'country_id_m1': 1, 'year_id_m1': 1, 'sex_id_m1': 3, 'life_expectancy_m1': 53.24999078, 'healthy_life_expectancy_m1': 45.9436686, 'country_id_m2': 1, 'year_id_m2': 1, 'sex_id_m2': 4, 'life_expectancy_m2': 53.82332641, 'healthy_life_expectancy_m2': 46.02795049, 'country_id_m3': 3, 'year_id_m3': 1, 'sex_id_m3': 2, 'life_expectancy_m3': 77.06220145, 'healthy_life_expectancy_m3': 66.80808734, 'country_id_m4': 3, 'year_id_m4': 1, 'sex_id_m4': 3, 'life_expectancy_m4': 70.6839866, 'healthy_life_expectancy_m4': 62.42516155, 'country_id_m5': 3, 'year_id_m5': 1, 'sex_id_m5': 4, 'life_expectancy_m5': 73.68285742, 'healthy_life_expectancy_m5': 64.47740779, 'country_id_m6': 48, 'year_id_m6': 1, 'sex_id_m6': 2, 'life_expectancy_m6': 73.80763424, 'healthy_life_expectancy_m6': 62.89042908, 'country_id_m7': 48, 'year_id_m7': 1, 'sex_id_m7': 3, 'life_expectancy_m7': 71.19099348, 'healthy_life_expectancy_m7': 62.97492652, 'country_id_m8': 48, 'year_id_m8': 1, 'sex_id_m8': 4, 'life_expectancy_m8': 72.46839135, 'healthy_life_expectancy_m8': 62.93614021, 'country_id_m9': 2, 'year_id_m9': 1, 'sex_id_m9': 2, 'life_expectancy_m9': 51.85894906, 'healthy_life_expectancy_m9': 44.43854811 ... 4900 parameters truncated ... 'country_id_m990': 177, 'year_id_m990': 2, 'sex_id_m990': 2, 'life_expectancy_m990': 76.19170405, 'healthy_life_expectancy_m990': 66.55883002, 'country_id_m991': 177, 'year_id_m991': 2, 'sex_id_m991': 3, 'life_expectancy_m991': 67.7428569, 'healthy_life_expectancy_m991': 61.13026211, 'country_id_m992': 177, 'year_id_m992': 2, 'sex_id_m992': 4, 'life_expectancy_m992': 71.97988323, 'healthy_life_expectancy_m992': 63.85565192, 'country_id_m993': 154, 'year_id_m993': 2, 'sex_id_m993': 2, 'life_expectancy_m993': 80.0826121, 'healthy_life_expectancy_m993': 68.49856524, 'country_id_m994': 154, 'year_id_m994': 2, 'sex_id_m994': 3, 'life_expectancy_m994': 72.19579867, 'healthy_life_expectancy_m994': 63.53244811, 'country_id_m995': 154, 'year_id_m995': 2, 'sex_id_m995': 4, 'life_expectancy_m995': 76.22393944, 'healthy_life_expectancy_m995': 66.07900003, 'country_id_m996': 148, 'year_id_m996': 2, 'sex_id_m996': 2, 'life_expectancy_m996': 51.64988019, 'healthy_life_expectancy_m996': 44.74765658, 'country_id_m997': 148, 'year_id_m997': 2, 'sex_id_m997': 3, 'life_expectancy_m997': 47.20073526, 'healthy_life_expectancy_m997': 42.26209632, 'country_id_m998': 148, 'year_id_m998': 2, 'sex_id_m998': 4, 'life_expectancy_m998': 49.32648692, 'healthy_life_expectancy_m998': 43.44347767, 'country_id_m999': 181, 'year_id_m999': 2, 'sex_id_m999': 2, 'life_expectancy_m999': 57.98181582, 'healthy_life_expectancy_m999': 49.27948773}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
print('Refresh Materialized Views')
try:
    with engine.begin() as conn:
        conn.execute(text('REFRESH MATERIALIZED VIEW mv_mortality_by_country;'))
        conn.execute(text('REFRESH MATERIALIZED VIEW mv_top_causes;'))
        conn.execute(text('REFRESH MATERIALIZED VIEW mv_life_expectancy_trend;'))
    print('Materialized views refreshed.')
except Exception as e:
    print(f'ERROR refresh MV: {e}')
# Out:
# >>> Refresh Materialized Views...
# Materialized views refreshed.

# %% [markdown]
# ### 3.3 Ukuran Database
#
# Menampilkan ukuran total database dan masing-masing tabel.

# %%
size_queries = [
    ('Database size', "SELECT pg_size_pretty(pg_database_size(current_database())) AS db_size"),
    ('fact_mortality size', "SELECT pg_size_pretty(pg_total_relation_size('fact_mortality')) AS size"),
    ('fact_life_expectancy size', "SELECT pg_size_pretty(pg_total_relation_size('fact_life_expectancy')) AS size"),
    ('dim_country size', "SELECT pg_size_pretty(pg_total_relation_size('dim_country')) AS size"),
    ('dim_cause size', "SELECT pg_size_pretty(pg_total_relation_size('dim_cause')) AS size"),
    ('dim_year size', "SELECT pg_size_pretty(pg_total_relation_size('dim_year')) AS size"),
    ('dim_sex size', "SELECT pg_size_pretty(pg_total_relation_size('dim_sex')) AS size"),
]

print('UKURAN DATABASE & TABEL')
print(f'{"Komponen":<35} {"Size":>15}')
print('-' * 50)

try:
    with engine.connect() as conn:
        for label, q in size_queries:
            result = conn.execute(text(q))
            val = result.scalar()
            print(f'{label:<35} {val:>15}')

        print('\n=== ROW COUNTS ===')
        for table in ['dim_country', 'dim_year', 'dim_cause', 'dim_sex',
                      'fact_mortality', 'fact_life_expectancy',
                      'mv_mortality_by_country', 'mv_top_causes', 'mv_life_expectancy_trend']:
            cnt = conn.execute(text(f'SELECT COUNT(*) FROM {table}')).scalar()
            print(f'  {table:<35} {cnt:>10,} rows')
except Exception as e:
    print(f'Error querying size: {e}')
# Out:
# === UKURAN DATABASE & TABEL ===
# Komponen                                       Size
# --------------------------------------------------
# Database size                                 12 MB
# fact_mortality size                         0 bytes
# fact_life_expectancy size                   0 bytes
# dim_country size                              72 kB
# dim_cause size                                72 kB
# dim_year size                                 24 kB
# dim_sex size                                  16 kB
#
# === ROW COUNTS ===
#   dim_country                                183 rows
#   dim_year                                    22 rows
#   dim_cause                                  134 rows
#   dim_sex                                      0 rows
#   fact_mortality                               0 rows
#   fact_life_expectancy                         0 rows
#   mv_mortality_by_country                      0 rows
#   mv_top_causes                                0 rows
#   mv_life_expectancy_trend                     0 rows

# %%
print('\nSEMUA TABEL')
try:
    with engine.connect() as conn:
        rows = conn.execute(text("""
            SELECT tablename,
                   pg_size_pretty(pg_total_relation_size(schemaname||'.'||tablename)) AS total_size,
                   pg_size_pretty(pg_relation_size(schemaname||'.'||tablename)) AS table_size,
                   pg_size_pretty(pg_indexes_size(schemaname||'.'||tablename)) AS index_size
            FROM pg_tables
            WHERE schemaname = 'public'
            ORDER BY pg_total_relation_size(schemaname||'.'||tablename) DESC
        """)).fetchall()
        print(f'{"Tabel":<40} {"Total Size":<15} {"Table Size":<15} {"Index Size":<15}')
        print('-' * 85)
        for r in rows:
            print(f'{r[0]:<40} {r[1]:<15} {r[2]:<15} {r[3]:<15}')
except Exception as e:
    print(f'Error: {e}')
# Out:
# === SEMUA TABEL (detail) ===
# Tabel                                    Total Size      Table Size      Index Size
# -------------------------------------------------------------------------------------
# fact_life_2000                           176 kB          40 kB           112 kB
# fact_life_2001                           168 kB          32 kB           112 kB
# dim_country                              72 kB           16 kB           32 kB
# dim_cause                                72 kB           16 kB           32 kB
# fact_mortality_2021                      40 kB           0 bytes         40 kB
# fact_mortality_2020                      40 kB           0 bytes         40 kB
# fact_life_2021                           32 kB           0 bytes         32 kB
# fact_life_2017                           32 kB           0 bytes         32 kB
# fact_life_2018                           32 kB           0 bytes         32 kB
# fact_life_2019                           32 kB           0 bytes         32 kB
# fact_life_2020                           32 kB           0 bytes         32 kB
# fact_life_2002                           32 kB           0 bytes         32 kB
# fact_life_2003                           32 kB           0 bytes         32 kB
# fact_life_2004                           32 kB           0 bytes         32 kB
# fact_life_2005                           32 kB           0 bytes         32 kB
# fact_life_2006                           32 kB           0 bytes         32 kB
# fact_life_2007                           32 kB           0 bytes         32 kB
# fact_life_2008                           32 kB           0 bytes         32 kB
# fact_life_2009                           32 kB           0 bytes         32 kB
# fact_life_2010                           32 kB           0 bytes         32 kB
# fact_life_2011                           32 kB           0 bytes         32 kB
# fact_life_2012                           32 kB           0 bytes         32 kB
# fact_life_2013                           32 kB           0 bytes         32 kB
# fact_life_2014                           32 kB           0 bytes         32 kB
# fact_life_2015                           32 kB           0 bytes         32 kB
# fact_life_2016                           32 kB           0 bytes         32 kB
# dim_year                                 24 kB           8192 bytes      16 kB
# dim_sex                                  16 kB           0 bytes         16 kB
# fact_life_expectancy                     0 bytes         0 bytes         0 bytes
# fact_mortality                           0 bytes         0 bytes         0 bytes

# %% [markdown]
# ---
# ## 4. Performance Benchmark
#
# Membandingkan kecepatan query: **Full Scan** vs **Partition Pruning** vs **Materialized View**.
#
# Setiap query dijalankan 3 kali, diambil rata-rata execution time. Menggunakan `EXPLAIN (ANALYZE, BUFFERS)`.

# %%
def parse_explain(output):
    exec_ms = None
    plan_ms = None
    hit = read = 0
    for line in output.split('\n'):
        m = re.search(r'Execution Time:\s*([\d.]+)\s*ms', line)
        if m: exec_ms = float(m.group(1))
        m = re.search(r'Planning Time:\s*([\d.]+)\s*ms', line)
        if m: plan_ms = float(m.group(1))
        m = re.search(r'shared hit=(\d+)', line)
        if m: hit = int(m.group(1))
        m = re.search(r'read=(\d+)', line)
        if m: read = int(m.group(1))
    return exec_ms, plan_ms, hit, read


benchmark_queries = [
    ('Q1 — Full Scan (all partitions)',
     "SELECT AVG(death_rate) FROM fact_mortality;"),
    ('Q2 — Partition Pruning (year_id=1 / 2021)',
     "SELECT AVG(death_rate) FROM fact_mortality WHERE year_id = 1;"),
    ('Q3 — Partition Pruning (year_id=2 / 2020)',
     "SELECT AVG(death_rate) FROM fact_mortality WHERE year_id = 2;"),
    ('Q4 — Materialized View (mv_mortality_by_country)',
     "SELECT COUNT(*), AVG(avg_death_rate) FROM mv_mortality_by_country;"),
    ('Q5 — Aggregation JOIN (live) — cause_category',
     """SELECT cs.cause_category, AVG(d.death_rate)\n"
     "FROM fact_mortality d\n"
     "JOIN dim_cause cs ON cs.cause_id = d.cause_id\n"
     "GROUP BY cs.cause_category;"""),
    ('Q6 — Aggregation via MV (mv_top_causes)',
     "SELECT cause_category, AVG(avg_death_rate) FROM mv_top_causes GROUP BY cause_category;"),
]

results = []

try:
    with engine.connect() as conn:
        for label, sql in benchmark_queries:
            times_exec = []
            times_plan = []
            hits = []
            reads = []
            for run in range(3):
                explain_sql = f"EXPLAIN (ANALYZE, BUFFERS) {sql}"
                result = conn.execute(text(explain_sql))
                output = '\n'.join(row[0] for row in result)
                exec_ms, plan_ms, hit, read = parse_explain(output)
                if exec_ms: times_exec.append(exec_ms)
                if plan_ms: times_plan.append(plan_ms)
                hits.append(hit)
                reads.append(read)
            avg_exec = np.mean(times_exec) if times_exec else 0
            avg_plan = np.mean(times_plan) if times_plan else 0
            avg_hit = np.mean(hits)
            avg_read = np.mean(reads)
            results.append({
                'Query': label,
                'Exec Time (ms)': round(avg_exec, 3),
                'Plan Time (ms)': round(avg_plan, 3),
                'Total (ms)': round(avg_exec + avg_plan, 3),
                'Buffers Hit': int(avg_hit),
                'Buffers Read': int(avg_read),
            })
            print(f'  {label:<50} {avg_exec:>8.3f} ms')
except Exception as e:
    print(f'Error benchmark: {e}')

df_benchmark = pd.DataFrame(results)
print('           HASIL BENCHMARK')
print(df_benchmark.to_string(index=False))
# Out:
#   Q1 — Full Scan (all partitions)                       0.058 ms
#   Q2 — Partition Pruning (year_id=1 / 2021)             0.059 ms
#   Q3 — Partition Pruning (year_id=2 / 2020)             0.043 ms
#   Q4 — Materialized View (mv_mortality_by_country)      0.041 ms
# Error benchmark: (psycopg2.errors.SyntaxError) syntax error at or near ""
#      ""
# LINE 4: "
#         ^
#
# [SQL: EXPLAIN (ANALYZE, BUFFERS) SELECT cs.cause_category, AVG(d.death_rate)
# "
#      "FROM fact_mortality d
# "
#      "JOIN dim_cause cs ON cs.cause_id = d.cause_id
# "
#      "GROUP BY cs.cause_category;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#
# ========================================
#            HASIL BENCHMARK
# ========================================
#                                            Query  Exec Time (ms)  Plan Time (ms)  Total (ms)  Buffers Hit  Buffers Read
#                  Q1 — Full Scan (all partitions)           0.058           0.135       0.193           10             0
#        Q2 — Partition Pruning (year_id=1 / 2021)           0.059           0.135       0.194            5             0
#        Q3 — Partition Pruning (year_id=2 / 2020)           0.043           0.145       0.187            5             0
# Q4 — Materialized View (mv_mortality_by_country)           0.041           0.060       0.101            0             0

# %%
print('\nPERBANDINGAN KINERJA')
print(f'\nSpeedup Partition Pruning vs Full Scan:')
if len(results) >= 3 and results[0]['Exec Time (ms)'] > 0:
    fs = results[0]['Exec Time (ms)']
    pp1 = results[1]['Exec Time (ms)']
    pp2 = results[2]['Exec Time (ms)']
    print(f'  Full Scan:          {fs:.3f} ms')
    print(f'  Partition Pruning 1:{pp1:.3f} ms ({fs/pp1:.2f}x lebih cepat)')
    print(f'  Partition Pruning 2:{pp2:.3f} ms ({fs/pp2:.2f}x lebih cepat)')

print(f'\nSpeedup Materialized View vs Live Aggregation:')
if len(results) >= 6:
    live = results[4]['Exec Time (ms)']
    mv = results[5]['Exec Time (ms)']
    if mv > 0:
        print(f'  Live JOIN Agg:      {live:.3f} ms')
        print(f'  Materialized View:  {mv:.3f} ms ({live/mv:.2f}x lebih cepat)')
# Out:
# === PERBANDINGAN KINERJA ===
#
# Speedup Partition Pruning vs Full Scan:
#   Full Scan:          0.058 ms
#   Partition Pruning 1:0.059 ms (0.98x lebih cepat)
#   Partition Pruning 2:0.043 ms (1.35x lebih cepat)
#
# Speedup Materialized View vs Live Aggregation:

# %% [markdown]
# ---
# ## 5. OLAP & Data Mart
#
# Menggunakan **Atoti** untuk OLAP cube. Jika Atoti/Java tidak tersedia, **fallback ke pandas pivot_table**.

# %%
df_mortality_flat = fact_mortality.merge(
    dim_country[['country_id', 'country_name', 'country_code']], on='country_id'
).merge(
    dim_year[['year_id', 'year']], on='year_id'
).merge(
    dim_cause[['cause_id', 'cause_name', 'cause_category']], on='cause_id'
).merge(
    dim_sex[['sex_id', 'sex_name']], on='sex_id'
)

print(f'Mortality flat table: {df_mortality_flat.shape}')
df_mortality_flat.head(3)
# Out:
# Mortality flat table: (147132, 11)
#    country_id  year_id  cause_id  sex_id  death_rate country_name  \
# 0           1       22       119       1        1.46  Afghanistan
# 1           1       22        52       1        0.00  Afghanistan
# 2           1       22        38       1        0.11  Afghanistan
#
#   country_code  year      cause_name cause_category    sex_name
# 0          AFG  2021        Syphilis   Communicable  Both sexes
# 1          AFG  2021  Genital herpes   Communicable  Both sexes
# 2          AFG  2021      Diphtheria   Communicable  Both sexes

# %%
try:
    import atoti as tt
    ATOTI_AVAIL = True
    session = tt.Session.start()
    print(f'Atoti tersedia! Dashboard: {session.url}')
except Exception as e:
    ATOTI_AVAIL = False
    print(f'Atoti tidak tersedia ({e}). Fallback ke pandas pivot_table.')
# Out:
# Welcome to Atoti 0.9.12!
#
# By using this community edition, you agree with the license available at https://docs.activeviam.com/products/atoti/python-sdk/latest/eula.html.
# Browse the official documentation at https://docs.activeviam.com/products/atoti/python-sdk.
# Join the community at https://www.atoti.io/register.
#
# Atoti collects telemetry data, which is used to help understand how to improve the product.
# If you don't wish to send usage data, you can request a trial license at https://www.atoti.io/evaluation-license-request.
#
# You can hide this message by setting the `ATOTI_HIDE_EULA_MESSAGE` environment variable to True.
# Atoti tidak tersedia (Could not retrieve the port of the Atoti Spring application from C:\Users\LENOVO\AppData\Local\Temp\tmpq1tdzljp within 120 seconds: Process exited with exit code 1
# Server logs:
# May 27, 2026 10:07:41 PM ActiveViam License log
# INFO: Activating ActiveViam Licensing Agent.
# May 27, 2026 10:07:41 PM com.activeviam.lic.licensing.private_.activation.LicenseManager a
# INFO: License has been found from environment variable ATOTI_LICENSE C:\Users\LENOVO\cobaatoti\Lib\site-packages\_atoti_server\__resources__\community.lic
# May 27, 2026 10:07:41 PM ActiveViam License log
# INFO:
# *************** Platform Information *****************
# System Time: May 27, 2026
# Number of Processors: 8
# MAC address: 70-08-94-36-9B-E3
# IP address: 192.168.1.161
# Hostname: LAPTOP-PJ41VKD4
# ******************************************************
#
# ********** Atoti License Information ***********
# License ID: 1ab67a46-2f9c-416e-9eda-7ed454d13803
# Client name: atoti community
# End Date: Mon May 04 11:00:00 ICT 2026
# Maximum Number of Processors: 0
# Restricted MAC address: -
# Restricted IP address: -
# Restricted Hostname: -
# On Demand: true
# On Demand License Server: AWS_EU_WEST_1_PROD
# Target Environment: -
# Datastore Enabled: true
# DirectQuery Enabled: false
# Atoti UI Enabled: true
# ActiveMonitor Enabled: true
# Collateral Optimizer Enabled: false
# Ai Enabled: false
# ******************************************************
#
# Atoti Server version: 6.1.16
# May 27, 2026 10:07:41 PM ActiveViam License log
# WARNING: The currently loaded license is set to expire in -23 days. Consider using a new one.
# May 27, 2026 10:07:42 PM ActiveViam License log
# SEVERE: Your license has expired, please contact ActiveViam to have a new one
# May 27, 2026 10:07:42 PM ActiveViam License log
# SEVERE: License status: Invalid
# May 27, 2026 10:07:42 PM ActiveViam License log
# SEVERE: License: Your license is not active: system date (May 27, 2026) is not between start date (January 1, 1970) and end date (May 4, 2026).
# Please contact ActiveViam.
# Exception in thread "main" java.lang.reflect.InvocationTargetException
# 	at java.base/jdk.internal.reflect.DirectMethodHandleAccessor.invoke(Unknown Source)
# 	at java.base/java.lang.reflect.Method.invoke(Unknown Source)
# 	at org.springframework.boot.loader.launch.Launcher.launch(Launcher.java:106)
# 	at org.springframework.boot.loader.launch.Launcher.launch(Launcher.java:64)
# 	at org.springframework.boot.loader.launch.PropertiesLauncher.main(PropertiesLauncher.java:580)
# Caused by: com.activeviam.tech.core.api.exceptions.ActiveViamRuntimeException: The license has expired, update to Atoti Community Edition's latest version or upgrade to Atoti.
# 	at com.activeviam.atoti.server.starter.private_.ApplicationStarter.checkLicense(ApplicationStarter.java:121)
# 	at com.activeviam.atoti.server.starter.private_.ApplicationStarter.fullInit(ApplicationStarter.java:104)
# 	at com.activeviam.atoti.server.starter.private_.ApplicationStarter.main(ApplicationStarter.java:51)
# 	... 5 more
# ). Fallback ke pandas pivot_table.

# %% [markdown]
# ### 5.1 OLAP Queries
#
# Menjalankan 6 query multidimensional menggunakan Atoti (jika avail) atau pandas.

# %%
if ATOTI_AVAIL:
    df_mortality_flat['year'] = df_mortality_flat['year'].astype(str)
    store = session.read_pandas(
        df_mortality_flat,
        table_name='mortality',
        keys=['country_id', 'year_id', 'cause_id', 'sex_id']
    )
    cube = session.create_cube(store, 'MortalityCube')
    m = cube.measures
    l = cube.levels

    MEAS_DEATH_RATE = m['death_rate.SUM']
    MEAN_DEATH_RATE = m['death_rate.MEAN']
    CNT_RECORDS     = m['contributors.COUNT']

    lev_country_name = l[('mortality', 'country_name', 'country_name')]
    lev_country_code = l[('mortality', 'country_code', 'country_code')]
    lev_cause_name   = l[('mortality', 'cause_name', 'cause_name')]
    lev_cause_cat    = l[('mortality', 'cause_category', 'cause_category')]
    lev_sex          = l[('mortality', 'sex_name', 'sex_name')]
    lev_year         = l[('mortality', 'year', 'year')]

    print(f'Measures: {list(m.keys())}')
    print('Cube configured!')
else:
    print('Menggunakan pandas pivot_table sebagai fallback...')
# Out:
# Menggunakan pandas pivot_table sebagai fallback...

# %%
if ATOTI_AVAIL:
    q1 = cube.query(
        MEAN_DEATH_RATE,
        levels=[lev_cause_name],
        filter=lev_sex == 'Both sexes'
    ).sort_values('death_rate.MEAN', ascending=False).head(10)
else:
    df_both_sex = df_mortality_flat[df_mortality_flat['sex_name'] == 'Both sexes']
    q1 = df_both_sex.groupby('cause_name')['death_rate'].mean().sort_values(ascending=False).head(10).reset_index()
    q1.columns = ['cause_name', 'death_rate.MEAN']

print('=== TOP 10 PENYEBAB KEMATIAN GLOBAL ===')
print(q1.to_string())
# Out:
# === TOP 10 PENYEBAB KEMATIAN GLOBAL ===
#                               cause_name  death_rate.MEAN
# 0                Ischaemic heart disease       116.524262
# 1                               COVID-19       110.503470
# 2                                 Stroke        77.190710
# 3           Lower respiratory infections        36.638552
# 4                      Diabetes mellitus        27.673470
# 5  Chronic obstructive pulmonary disease        22.290984
# 6             Hypertensive heart disease        21.693770
# 7                        Kidney diseases        20.846339
# 8  Alzheimer disease and other dementias        20.317213
# 9                           Tuberculosis        19.321803

# %%
if ATOTI_AVAIL:
    q2 = cube.query(
        m['death_rate.MEAN'],
        levels=[lev_country_name],
        filter=lev_sex == 'Both sexes'
    ).sort_values('death_rate.MEAN', ascending=False).head(10)
else:
    q2 = df_both_sex.groupby('country_name')['death_rate'].mean().sort_values(ascending=False).head(10).reset_index()
    q2.columns = ['country_name', 'death_rate.MEAN']

print('=== TOP 10 NEGARA TINGKAT KEMATIAN TERTINGGI ===')
print(q2.to_string())
# Out:
# === TOP 10 NEGARA TINGKAT KEMATIAN TERTINGGI ===
#              country_name  death_rate.MEAN
# 0                Bulgaria        14.990970
# 1                  Serbia        13.722015
# 2                  Latvia        12.435672
# 3  Bosnia and Herzegovina        12.348955
# 4                 Romania        11.893918
# 5               Lithuania        11.843694
# 6                 Ukraine        11.615784
# 7    Moldova, Republic of        11.597313
# 8      Russian Federation        11.126754
# 9                 Hungary        11.087201

# %%
if ATOTI_AVAIL:
    q3_all = cube.query(
        m['death_rate.MEAN'],
        levels=[lev_cause_name, lev_sex],
        filter=lev_sex != "Both sexes"
    )
    q3 = q3_all.reset_index()
else:
    df_no_both = df_mortality_flat[df_mortality_flat['sex_name'] != 'Both sexes']
    q3 = df_no_both.groupby(['cause_name', 'sex_name'])['death_rate'].mean().reset_index()
    q3.columns = ['cause_name', 'sex_name', 'death_rate.MEAN']

top_cause_list = ['Ischaemic heart disease', 'Stroke', 'COVID-19',
    'Lower respiratory infections', 'Tuberculosis',
    'Diabetes mellitus', 'Chronic obstructive pulmonary disease']
q3 = q3[q3['cause_name'].isin(top_cause_list)]
print('=== PERBANDINGAN GENDER — PENYEBAB UTAMA ===')
print(q3.to_string())
# Out:
# === PERBANDINGAN GENDER — PENYEBAB UTAMA ===
#                                 cause_name sex_name  death_rate.MEAN
# 38                                COVID-19   Female        94.553852
# 39                                COVID-19     Male       127.392486
# 52   Chronic obstructive pulmonary disease   Female        19.687923
# 53   Chronic obstructive pulmonary disease     Male        24.978934
# 70                       Diabetes mellitus   Female        30.614617
# 71                       Diabetes mellitus     Male        24.424317
# 130                Ischaemic heart disease   Female       113.174563
# 131                Ischaemic heart disease     Male       120.229454
# 146           Lower respiratory infections   Female        34.643333
# 147           Lower respiratory infections     Male        38.718825
# 232                                 Stroke   Female        83.774344
# 233                                 Stroke     Male        69.609153
# 254                           Tuberculosis   Female        15.309290
# 255                           Tuberculosis     Male        23.038415

# %%
if ATOTI_AVAIL:
    q4 = cube.query(
        m['death_rate.MEAN'],
        levels=[lev_cause_name, lev_sex],
        include_totals=True
    )
else:
    q4 = df_mortality_flat.groupby(['cause_name', 'sex_name'])['death_rate'].agg(['mean', 'sum', 'count']).reset_index()

print('MULTI-DIMENSIONAL')
if ATOTI_AVAIL:
    print(q4.head(20).to_string())
else:
    print(q4.head(20).to_string())
# Out:
# === MULTI-DIMENSIONAL (CUBE) ===
#                                cause_name    sex_name       mean       sum  count
# 0                       Acute hepatitis A  Both sexes   0.211995     77.59    366
# 1                       Acute hepatitis A      Female   0.207131     75.81    366
# 2                       Acute hepatitis A        Male   0.219344     80.28    366
# 3                       Acute hepatitis B  Both sexes   0.422814    154.75    366
# 4                       Acute hepatitis B      Female   0.298934    109.41    366
# 5                       Acute hepatitis B        Male   0.562596    205.91    366
# 6                       Acute hepatitis C  Both sexes   0.218470     79.96    366
# 7                       Acute hepatitis C      Female   0.156585     57.31    366
# 8                       Acute hepatitis C        Male   0.290710    106.40    366
# 9                       Acute hepatitis E  Both sexes   0.031694     11.60    366
# 10                      Acute hepatitis E      Female   0.018825      6.89    366
# 11                      Acute hepatitis E        Male   0.044863     16.42    366
# 12                African trypanosomiasis  Both sexes   0.052268     19.13    366
# 13                African trypanosomiasis      Female   0.052322     19.15    366
# 14                African trypanosomiasis        Male   0.055492     20.31    366
# 15                  Alcohol use disorders  Both sexes   2.522623    923.28    366
# 16                  Alcohol use disorders      Female   0.861230    315.21    366
# 17                  Alcohol use disorders        Male   4.216858   1543.37    366
# 18  Alzheimer disease and other dementias  Both sexes  20.317213   7436.10    366
# 19  Alzheimer disease and other dementias      Female  27.418197  10035.06    366

# %%
if ATOTI_AVAIL:
    q5_all = cube.query(
        m['death_rate.MEAN'],
        levels=[lev_cause_name, lev_year],
        filter=lev_sex == "Both sexes"
    )
    q5 = q5_all.reset_index()
else:
    q5 = df_both_sex.groupby(['cause_name', 'year'])['death_rate'].mean().reset_index()
    q5.columns = ['cause_name', 'year', 'death_rate.MEAN']

top5_list = ['Ischaemic heart disease', 'Stroke', 'COVID-19',
    'Lower respiratory infections', 'Chronic obstructive pulmonary disease']
q5 = q5[q5['cause_name'].isin(top5_list)]
print('=== YEAR-OVER-YEAR: TOP 5 CAUSES ===')
print(q5.to_string())
# Out:
# === YEAR-OVER-YEAR: TOP 5 CAUSES ===
#                                 cause_name  year  death_rate.MEAN
# 38                                COVID-19  2020       110.109508
# 39                                COVID-19  2021       110.897432
# 52   Chronic obstructive pulmonary disease  2020        22.312678
# 53   Chronic obstructive pulmonary disease  2021        22.269290
# 130                Ischaemic heart disease  2020       116.644044
# 131                Ischaemic heart disease  2021       116.404481
# 146           Lower respiratory infections  2020        36.503661
# 147           Lower respiratory infections  2021        36.773443
# 232                                 Stroke  2020        77.499508
# 233                                 Stroke  2021        76.881913

# %%
if ATOTI_AVAIL:
    q6 = cube.query(
        m['death_rate.MEAN'],
        levels=[lev_cause_cat, lev_cause_name, lev_sex],
        include_totals=True
    )
else:
    q6 = df_mortality_flat.groupby(['cause_category', 'cause_name', 'sex_name'])['death_rate'].mean().reset_index()
    q6.columns = ['cause_category', 'cause_name', 'sex_name', 'death_rate.MEAN']

print('=== DRILL-DOWN: CATEGORY > CAUSE x SEX ===')
print(q6.head(25).to_string())
# Out:
# === DRILL-DOWN: CATEGORY > CAUSE x SEX ===
#    cause_category                       cause_name    sex_name  death_rate.MEAN
# 0    Communicable                Acute hepatitis A  Both sexes         0.211995
# 1    Communicable                Acute hepatitis A      Female         0.207131
# 2    Communicable                Acute hepatitis A        Male         0.219344
# 3    Communicable                Acute hepatitis B  Both sexes         0.422814
# 4    Communicable                Acute hepatitis B      Female         0.298934
# 5    Communicable                Acute hepatitis B        Male         0.562596
# 6    Communicable                Acute hepatitis C  Both sexes         0.218470
# 7    Communicable                Acute hepatitis C      Female         0.156585
# 8    Communicable                Acute hepatitis C        Male         0.290710
# 9    Communicable                Acute hepatitis E  Both sexes         0.031694
# 10   Communicable                Acute hepatitis E      Female         0.018825
# 11   Communicable                Acute hepatitis E        Male         0.044863
# 12   Communicable          African trypanosomiasis  Both sexes         0.052268
# 13   Communicable          African trypanosomiasis      Female         0.052322
# 14   Communicable          African trypanosomiasis        Male         0.055492
# 15   Communicable                       Ascariasis  Both sexes         0.071503
# 16   Communicable                       Ascariasis      Female         0.071475
# 17   Communicable                       Ascariasis        Male         0.070847
# 18   Communicable  Birth asphyxia and birth trauma  Both sexes         7.830574
# 19   Communicable  Birth asphyxia and birth trauma      Female         6.826421
# 20   Communicable  Birth asphyxia and birth trauma        Male         8.761885
# 21   Communicable                         COVID-19  Both sexes       110.503470
# 22   Communicable                         COVID-19      Female        94.553852
# 23   Communicable                         COVID-19        Male       127.392486
# 24   Communicable                   Chagas disease  Both sexes         0.065437

# %% [markdown]
# ---
# ## 6. Visualisasi
#
# 5 grafik insight dari data kematian global menggunakan matplotlib & seaborn.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['figure.dpi'] = 100

# %%
# Plot 1: Top 10 Causes
plt.figure(figsize=(12, 6))
top_causes = q1.reset_index() if ATOTI_AVAIL else q1
sns.barplot(data=top_causes.head(10), y='cause_name', x='death_rate.MEAN',
            palette=sns.color_palette('Reds_r', 10))
plt.title('Top 10 Penyebab Kematian — Rata-rata Global (2020-2021)', fontsize=14, fontweight='bold')
plt.xlabel('Rata-rata Tingkat Kematian (per 100.000)')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))
q3_plot = q3.reset_index() if ATOTI_AVAIL else q3
sns.barplot(data=q3_plot, x='death_rate.MEAN', y='cause_name',
            hue='sex_name', palette='Set2')
plt.title('Perbandingan Gender: Tingkat Kematian Penyebab Utama', fontsize=14, fontweight='bold')
plt.xlabel('Rata-rata Tingkat Kematian (per 100.000)')
plt.ylabel('')
plt.legend(title='Jenis Kelamin')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
top_ctry = q2.reset_index() if ATOTI_AVAIL else q2
sns.barplot(data=top_ctry.head(10), x='death_rate.MEAN', y='country_name',
            palette='Blues_r')
plt.title('10 Negara dengan Tingkat Kematian Tertinggi', fontsize=14, fontweight='bold')
plt.xlabel('Rata-rata Tingkat Kematian (per 100.000)')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
# Plot 4: Year-over-Year Comparison
plt.figure(figsize=(14, 6))
q5_plot = q5.reset_index() if ATOTI_AVAIL else q5
sns.barplot(data=q5_plot, x='year', y='death_rate.MEAN',
            hue='cause_name', palette='tab10')
plt.title('Perbandingan 2020 vs 2021 — Top 5 Causes', fontsize=14, fontweight='bold')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata Tingkat Kematian (per 100.000)')
plt.legend(title='Penyebab', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Plot 5: Distribution by Cause Category
if ATOTI_AVAIL:
    q_cat = cube.query(
        m['death_rate.MEAN'],
        levels=[lev_cause_cat],
        filter=lev_sex == 'Both sexes'
    ).reset_index()
else:
    q_cat = df_both_sex.groupby('cause_category')['death_rate'].mean().reset_index()
    q_cat.columns = ['cause_category', 'death_rate.MEAN']

plt.figure(figsize=(10, 8))
plt.pie(q_cat['death_rate.MEAN'], labels=q_cat['cause_category'],
        autopct='%1.1f%%', colors=sns.color_palette('Set3', 10),
        startangle=90, explode=[0.03]*len(q_cat))
plt.title('Distribusi Tingkat Kematian per Kategori Penyebab', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 7. Export Data (CSV)

# %%
dim_country.to_csv('dim_country.csv', index=False)
dim_year.to_csv('dim_year.csv', index=False)
dim_cause.to_csv('dim_cause.csv', index=False)
dim_sex.to_csv('dim_sex.csv', index=False)
fact_mortality.to_csv('fact_mortality.csv', index=False)
fact_life.to_csv('fact_life_expectancy.csv', index=False)
print('Ekspor CSV selesai.')
# Out:
# Ekspor CSV selesai.
